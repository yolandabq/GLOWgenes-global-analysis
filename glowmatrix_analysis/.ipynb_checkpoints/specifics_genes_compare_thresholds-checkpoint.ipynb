# %% [markdown]
# # Genes específicos de panel

# %% [markdown]
# Vamos a considerar que los genes específicos de panel son aquellos que están en el top en muy pocos paneles y en el "bottom" la mayoría de las veces.
# Elegimos los threshold:
# - TOP: por encima del top 0.01
# - BOTTOM: por debajo de 0.5

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('/home/yolanda/tblab/yolanda/GLOWgenes/panelAPP/analysis/glow_matrix_clustered_no_NA.tsv',sep = '\t') 
df.head()
#df_np = df.set_index('SYMBOL').fillna(df.set_index('SYMBOL').max()).to_numpy()
gene_disease_matrix = df.set_index('SYMBOL')


panel_class = pd.read_csv('/home/yolanda/tblab/yolanda/GLOWgenes/panelAPP/analysis/filter_panels/final_reclasified_panels.tsv',sep = '\t', header=None)

# %%
panels_to_remove=pd.read_csv('/home/yolanda/tblab/yolanda/GLOWgenes/panelAPP/analysis/filter_panels/panels_including_others.txt',sep = '\t', header=None) 
list(panels_to_remove[0])
# Out:
# ['Dilated_and_arrhythmogenic_cardiomyopathy',
#  'Ectodermal_dysplasia',
#  'Thoracic_aortic_aneurysm_or_dissection_(GMS)',
#  'Childhood_solid_tumours_cancer_susceptibility',
#  'Adult_solid_tumours_for_rare_disease',
#  'Sarcoma_susceptibility',
#  'Childhood_solid_tumours',
#  'Undiagnosed_metabolic_disorders',
#  'Lysosomal_storage_disorder',
#  'Albinism_or_congenital_nystagmus',
#  'Mitochondrial_disorders',
#  'Ichthyosis_and_erythrokeratoderma',
#  'Unexplained_young_onset_end-stage_renal_disease',
#  'Lipodystrophy_-_childhood_onset',
#  'Skeletal_dysplasia',
#  'Structural_eye_disease',
#  'Adult_solid_tumours_cancer_susceptibility',
#  'Sarcoma_cancer_susceptibility',
#  'Adult_onset_neurodegenerative_disorder',
#  'Epidermolysis_bullosa_and_congenital_skin_fragility',
#  'Paediatric_or_syndromic_cardiomyopathy',
#  'Haematological_malignancies_cancer_susceptibility',
#  'Haematological_malignancies_for_rare_disease',
#  'Likely_inborn_error_of_metabolism_-_targeted_testing_not_possible',
#  'Ophthalmological_ciliopathies',
#  'GI_tract_tumours']

# %% [markdown]
# Eliminamos los paneles que contienen al 100% a otros.

# %%
panel_class = panel_class[~panel_class[1].isin(list(panels_to_remove[0]))]

# %% [markdown]
# Añadimos "_GA"

# %%
panel_list = [str(x + "_GA") for x in panel_class[1]]
panel_class[1] = panel_list

# %%
panel_class
# Out:
#                                      0  \
# 2    Cancer Programme+Tumour syndromes
# 4    Cancer Programme+Tumour syndromes
# 5    Cancer Programme+Tumour syndromes
# 6    Cancer Programme+Tumour syndromes
# 9             Cardiovascular disorders
# ..                                 ...
# 204  Cancer Programme+Tumour syndromes
# 205  Cancer Programme+Tumour syndromes
# 206  Cancer Programme+Tumour syndromes
# 207  Cancer Programme+Tumour syndromes
# 208  Cancer Programme+Tumour syndromes
#
#                                                      1
# 2    Colorectal_cancer_pertinent_cancer_susceptibil...
# 4    Head_and_neck_cancer_pertinent_cancer_suscepti...
# 5    Neuroendocrine_cancer_pertinent_cancer_suscept...
# 6      Renal_cancer_pertinent_cancer_susceptibility_GA
# 9    Arrhythmogenic_right_ventricular_cardiomyopath...
# ..                                                 ...
# 204  Inherited_phaeochromocytoma_and_paraganglioma_...
# 205  Inherited_predisposition_to_acute_myeloid_leuk...
# 206                          Inherited_renal_cancer_GA
# 207                      Multiple_endocrine_tumours_GA
# 208                        Neurofibromatosis_Type_1_GA
#
# [183 rows x 2 columns]

# %%
from collections import Counter

d = Counter(panel_class[0])
d
# Out:
# Counter({'Neurology and neurodevelopmental disorders': 43,
#          'Cancer Programme+Tumour syndromes': 16,
#          'Endocrine disorders': 15,
#          'Metabolic disorders': 14,
#          'Cardiovascular disorders': 11,
#          'Dermatological disorders': 11,
#          'Dysmorphic and congenital abnormality syndromes': 10,
#          'Gastroenterological disorders': 10,
#          'Ophthalmological disorders': 10,
#          'Renal and urinary tract disorders': 10,
#          'Haematological and immunological disorders': 9,
#          'Skeletal disorders': 8,
#          'Ciliopathies': 7,
#          'Respiratory disorders': 3,
#          'Growth disorders': 2,
#          'Hearing and ear disorders': 2,
#          'Rheumatological disorders': 2})

# %% [markdown]
# Extraemos de la matriz solo los paneles que queremos analizar.

# %%
gene_disease_matrix=gene_disease_matrix.loc[:,panel_list] # quitamos los paneles que están incluidos en otros.

# %%
gene_disease_matrix # 183 columnas
# Out:
#          Colorectal_cancer_pertinent_cancer_susceptibility_GA  \
# SYMBOL
# FAAP20                                              5773.0
# FANCM                                                 64.0
# POT1                                                 413.0
# FAAP100                                             1559.0
# XRCC3                                                107.0
# ...                                                    ...
# MTSS1L                                             19557.0
# C2orf71                                            19557.0
# FAM57B                                             19557.0
# FAM92A                                             19557.0
# WISP3                                              19557.0
#
#          Head_and_neck_cancer_pertinent_cancer_susceptibility_GA  \
# SYMBOL
# FAAP20                                                 4.0
# FANCM                                                  0.0
# POT1                                                 394.0
# FAAP100                                                1.0
# XRCC3                                                 32.0
# ...                                                    ...
# MTSS1L                                             22726.0
# C2orf71                                            22726.0
# FAM57B                                             22726.0
# FAM92A                                             22726.0
# WISP3                                              22726.0
#
#          Neuroendocrine_cancer_pertinent_cancer_susceptibility_GA  \
# SYMBOL
# FAAP20                                             13424.0
# FANCM                                               6109.0
# POT1                                                6885.0
# FAAP100                                            10504.0
# XRCC3                                               2606.0
# ...                                                    ...
# MTSS1L                                             19661.0
# C2orf71                                            19661.0
# FAM57B                                             19661.0
# FAM92A                                             19661.0
# WISP3                                              19661.0
#
#          Renal_cancer_pertinent_cancer_susceptibility_GA  \
# SYMBOL
# FAAP20                                            5967.0
# FANCM                                              579.0
# POT1                                              2316.0
# FAAP100                                           1392.0
# XRCC3                                              566.0
# ...                                                  ...
# MTSS1L                                           19570.0
# C2orf71                                          19570.0
# FAM57B                                           19570.0
# FAM92A                                           19570.0
# WISP3                                            19570.0
#
#          Arrhythmogenic_right_ventricular_cardiomyopathy_GA  \
# SYMBOL
# FAAP20                                             15627.0
# FANCM                                               3181.0
# POT1                                                1846.0
# FAAP100                                            13018.0
# XRCC3                                               5914.0
# ...                                                    ...
# MTSS1L                                             22270.0
# C2orf71                                            22270.0
# FAM57B                                             22270.0
# FAM92A                                             22270.0
# WISP3                                              22270.0
#
#          ClinGen_Familial_thoracic_aortic_aneurysm_and_aortic_dissection_GA  \
# SYMBOL
# FAAP20                                             17947.0
# FANCM                                               3460.0
# POT1                                               15023.0
# FAAP100                                            16063.0
# XRCC3                                               5296.0
# ...                                                    ...
# MTSS1L                                             22353.0
# C2orf71                                            22353.0
# FAM57B                                             22353.0
# FAM92A                                             22353.0
# WISP3                                              22353.0
#
#          Dilated_Cardiomyopathy_and_conduction_defects_GA  \
# SYMBOL
# FAAP20                                            16494.0
# FANCM                                              3242.0
# POT1                                               6605.0
# FAAP100                                           17750.0
# XRCC3                                             10028.0
# ...                                                   ...
# MTSS1L                                            20524.0
# C2orf71                                           20524.0
# FAM57B                                            20524.0
# FAM92A                                            20524.0
# WISP3                                             20524.0
#
#          Familial_cerebral_small_vessel_disease_GA  \
# SYMBOL
# FAAP20                                     16854.0
# FANCM                                       7658.0
# POT1                                       13689.0
# FAAP100                                    15239.0
# XRCC3                                       4564.0
# ...                                            ...
# MTSS1L                                     19592.0
# C2orf71                                    19592.0
# FAM57B                                     19592.0
# FAM92A                                     19592.0
# WISP3                                      19592.0
#
#          Familial_non_syndromic_congenital_heart_disease_GA  \
# SYMBOL
# FAAP20                                             15375.0
# FANCM                                               1238.0
# POT1                                               12507.0
# FAAP100                                             9291.0
# XRCC3                                               6325.0
# ...                                                    ...
# MTSS1L                                             19673.0
# C2orf71                                            19673.0
# FAM57B                                             19673.0
# FAM92A                                             19673.0
# WISP3                                              19673.0
#
#          Hypertrophic_cardiomyopathy_GA  ...  Familial_rhabdomyosarcoma_GA  \
# SYMBOL                                   ...
# FAAP20                          17637.0  ...                        5818.0
# FANCM                           11642.0  ...                         143.0
# POT1                            14375.0  ...                         943.0
# FAAP100                         17731.0  ...                        2797.0
# XRCC3                            7421.0  ...                         219.0
# ...                                 ...  ...                           ...
# MTSS1L                          21736.0  ...                       19586.0
# C2orf71                         21736.0  ...                       19586.0
# FAM57B                          21736.0  ...                       19586.0
# FAM92A                          21736.0  ...                       19586.0
# WISP3                           21736.0  ...                       19586.0
#
#          Familial_Tumours_Syndromes_of_the_central_&_peripheral_Nervous_system_GA  \
# SYMBOL
# FAAP20                                              8198.0
# FANCM                                                189.0
# POT1                                                4015.0
# FAAP100                                             2451.0
# XRCC3                                                255.0
# ...                                                    ...
# MTSS1L                                             19701.0
# C2orf71                                            19701.0
# FAM57B                                             19701.0
# FAM92A                                             19701.0
# WISP3                                              19701.0
#
#          Inherited_ovarian_cancer_(without_breast_cancer)_GA  \
# SYMBOL
# FAAP20                                               564.0
# FANCM                                                 20.0
# POT1                                                 260.0
# FAAP100                                              180.0
# XRCC3                                                  1.0
# ...                                                    ...
# MTSS1L                                             22256.0
# C2orf71                                            22256.0
# FAM57B                                             22256.0
# FAM92A                                             22256.0
# WISP3                                              22256.0
#
#          Inherited_pancreatic_cancer_GA  \
# SYMBOL
# FAAP20                            493.0
# FANCM                              65.0
# POT1                               59.0
# FAAP100                           176.0
# XRCC3                              73.0
# ...                                 ...
# MTSS1L                          22256.0
# C2orf71                         22256.0
# FAM57B                          22256.0
# FAM92A                          22256.0
# WISP3                           22256.0
#
#          Inherited_phaeochromocytoma_and_paraganglioma_GA  \
# SYMBOL
# FAAP20                                            13937.0
# FANCM                                              6115.0
# POT1                                              10747.0
# FAAP100                                           11121.0
# XRCC3                                              1922.0
# ...                                                   ...
# MTSS1L                                            19579.0
# C2orf71                                           19579.0
# FAM57B                                            19579.0
# FAM92A                                            19579.0
# WISP3                                             19579.0
#
#          Inherited_phaeochromocytoma_and_paraganglioma_excluding_NF1_GA  \
# SYMBOL
# FAAP20                                             14695.0
# FANCM                                               7112.0
# POT1                                               11748.0
# FAAP100                                            13732.0
# XRCC3                                               3057.0
# ...                                                    ...
# MTSS1L                                             19655.0
# C2orf71                                            19655.0
# FAM57B                                             19655.0
# FAM92A                                             19655.0
# WISP3                                              19655.0
#
#          Inherited_predisposition_to_acute_myeloid_leukaemia_(AML)_GA  \
# SYMBOL
# FAAP20                                              9970.0
# FANCM                                                316.0
# POT1                                                  13.0
# FAAP100                                              966.0
# XRCC3                                                400.0
# ...                                                    ...
# MTSS1L                                             19688.0
# C2orf71                                            19688.0
# FAM57B                                             19688.0
# FAM92A                                             19688.0
# WISP3                                              19688.0
#
#          Inherited_renal_cancer_GA  Multiple_endocrine_tumours_GA  \
# SYMBOL
# FAAP20                     11996.0                        12204.0
# FANCM                       6501.0                         3855.0
# POT1                         120.0                         4663.0
# FAAP100                    10167.0                        10262.0
# XRCC3                       2021.0                         3741.0
# ...                            ...                            ...
# MTSS1L                     19573.0                        19737.0
# C2orf71                    19573.0                        19737.0
# FAM57B                     19573.0                        19737.0
# FAM92A                     19573.0                        19737.0
# WISP3                      19573.0                        19737.0
#
#          Neurofibromatosis_Type_1_GA
# SYMBOL
# FAAP20                           4.0
# FANCM                            1.0
# POT1                           475.0
# FAAP100                          2.0
# XRCC3                           11.0
# ...                              ...
# MTSS1L                       22228.0
# C2orf71                      22228.0
# FAM57B                       22228.0
# FAM92A                       22228.0
# WISP3                        22228.0
#
# [24757 rows x 183 columns]

# %% [markdown]
# Ponemos los **thresholds**

# %%
threshold_top=0.01 # por encima de
threshold_bottom=0.5 # por debajo de

# %%
max_valuedisease=gene_disease_matrix.loc[:, gene_disease_matrix.columns != "Cluster"].max(axis=0) # el valor máximo de cada uno de los paneles.

# %%
max_valuedisease
# Out:
# Colorectal_cancer_pertinent_cancer_susceptibility_GA                                  19557.0
# Head_and_neck_cancer_pertinent_cancer_susceptibility_GA                               22726.0
# Neuroendocrine_cancer_pertinent_cancer_susceptibility_GA                              19661.0
# Renal_cancer_pertinent_cancer_susceptibility_GA                                       19570.0
# Arrhythmogenic_right_ventricular_cardiomyopathy_GA                                    22270.0
# ClinGen_Familial_thoracic_aortic_aneurysm_and_aortic_dissection_GA                    22353.0
# Dilated_Cardiomyopathy_and_conduction_defects_GA                                      20524.0
# Familial_cerebral_small_vessel_disease_GA                                             19592.0
# Familial_non_syndromic_congenital_heart_disease_GA                                    19673.0
# Hypertrophic_cardiomyopathy_GA                                                        21736.0
# Long_QT_syndrome_GA                                                                   22247.0
# Primary_lymphoedema_GA                                                                19492.0
# Progressive_cardiac_conduction_disease_GA                                             22238.0
# Pulmonary_arterial_hypertension_GA                                                    19514.0
# Vascular_skin_disorders_GA                                                            19544.0
# Bardet_Biedl_syndrome_GA                                                              21007.0
# Neurological_ciliopathies_GA                                                          22196.0
# Primary_ciliary_disorders_GA                                                          22312.0
# Rare_multisystem_ciliopathy_disorders_GA                                              20938.0
# Renal_ciliopathies_GA                                                                 21738.0
# Respiratory_ciliopathies_including_non-CF_bronchiectasis_GA                           21142.0
# Skeletal_ciliopathies_GA                                                              22213.0
# Autosomal_recessive_congenital_ichthyosis_GA                                          19497.0
# Cutaneous_photosensitivity_with_a_likely_genetic_cause_GA                             19511.0
# Ectodermal_dysplasia_without_a_known_gene_mutation_GA                                 19688.0
# Epidermolysis_bullosa_GA                                                              21793.0
# Non-syndromic_hypotrichosis_GA                                                        20531.0
# Palmoplantar_keratoderma_and_erythrokeratodermas_GA                                   21135.0
# Mosaic_skin_disorders_-_deep_sequencing_GA                                            19561.0
# Palmoplantar_keratodermas_GA                                                          19546.0
# Pigmentary_skin_disorders_GA                                                          19552.0
# Primary_immunodeficiency_or_monogenic_inflammatory_bowel_disease_GA                   22417.0
# Clefting_GA                                                                           19645.0
# Fetal_anomalies_GA                                                                    19586.0
# Fetal_hydrops_GA                                                                      20484.0
# Laterality_disorders_and_isomerism_GA                                                 21136.0
# Radial_dysplasia_GA                                                                   22705.0
# RASopathies_GA                                                                        22805.0
# Severe_microcephaly_GA                                                                22019.0
# VACTERL-like_phenotypes_GA                                                            19464.0
# Vici_Syndrome_and_other_autophagy_disorders_GA                                        19699.0
# Xeroderma_pigmentosum,_Trichothiodystrophy_or_Cockayne_syndrome_GA                    22717.0
# Congenital_adrenal_hypoplasia_GA                                                      19734.0
# Congenital_hyperinsulinism_GA                                                         19644.0
# Congenital_hypothyroidism_GA                                                          19660.0
# Diabetes_with_additional_phenotypes_suggestive_of_a_monogenic_aetiology_GA            19479.0
# Disorders_of_sex_development_GA                                                       19494.0
# Familial_diabetes_GA                                                                  22197.0
# Familial_hyperparathyroidism_or_hypocalciuric_hypercalcaemia_GA                       19576.0
# Hypogonadotropic_hypogonadism_(GMS)_GA                                                19652.0
# Insulin_resistance_(including_lipodystrophy)_GA                                       19526.0
# IUGR_and_IGF_abnormalities_GA                                                         19435.0
# Monogenic_diabetes_GA                                                                 22305.0
# Neonatal_diabetes_GA                                                                  22209.0
# Pituitary_hormone_deficiency_GA                                                       19736.0
# Primary_ovarian_insufficiency_GA                                                      19411.0
# Severe_early-onset_obesity_GA                                                         21018.0
# Cholestasis_GA                                                                        19494.0
# Ductal_plate_malformation_GA                                                          19716.0
# Familial_Hirschsprung_Disease_GA                                                      19724.0
# Gastrointestinal_epithelial_barrier_disorders_GA                                      20426.0
# Gastrointestinal_neuromuscular_disorders_GA                                           20421.0
# Infantile_enterocolitis_&_monogenic_inflammatory_bowel_disease_GA                     20419.0
# Intestinal_failure_or_congenital_diarrhoea_GA                                         22700.0
# Neonatal_cholestasis_GA                                                               19503.0
# Non-syndromic_familial_congenital_anorectal_malformations_GA                          20555.0
# Paediatric_pseudo-obstruction_syndrome_GA                                             19589.0
# Beckwith-Wiedemann_syndrome_(BWS)_and_other_congenital_overgrowth_disorders_GA        22224.0
# Growth_failure_in_early_childhood_GA                                                  22257.0
# Inherited_bleeding_disorders_GA                                                       19452.0
# Autoinflammatory_disorders_GA                                                         19753.0
# Bleeding_and_platelet_disorders_GA                                                    20353.0
# Confirmed_Fanconi_anaemia_or_Bloom_syndrome_GA                                        22228.0
# Cytopenia_-_NOT_Fanconi_anaemia_GA                                                    20440.0
# Cytopenias_and_congenital_anaemias_GA                                                 22224.0
# Hereditary_Erythrocytosis_GA                                                          19696.0
# Rare_anaemia_GA                                                                       19768.0
# Thrombophilia_with_a_likely_monogenic_cause_GA                                        19523.0
# Corneal_dystrophy_GA                                                                  19512.0
# Deafness_and_congenital_structural_abnormalities_GA                                   22304.0
# Monogenic_hearing_loss_GA                                                             19536.0
# Congenital_disorders_of_glycosylation_GA                                              20890.0
# Hyperammonaemia_GA                                                                    19638.0
# Hypophosphataemia_or_rickets_GA                                                       19740.0
# Iron_metabolism_disorders_-_NOT_common_HFE_mutations_GA                               19708.0
# Ketotic_hypoglycaemia_GA                                                              19578.0
# Mitochondrial_disorder_with_complex_I_deficiency_GA                                   20415.0
# Mitochondrial_disorder_with_complex_III_deficiency_GA                                 20981.0
# Mitochondrial_disorder_with_complex_IV_deficiency_GA                                  21763.0
# Mitochondrial_disorder_with_complex_V_deficiency_GA                                   20973.0
# Mitochondrial_DNA_maintenance_disorder_GA                                             21131.0
# Mucopolysaccharideosis,_Gaucher,_Fabry_GA                                             19555.0
# Peroxisomal_disorders_GA                                                              20483.0
# Pyruvate_dehydrogenase_(PDH)_deficiency_GA                                            19407.0
# Glycogen_storage_disease_GA                                                           19607.0
# Acute_rhabdomyolysis_GA                                                               19522.0
# Adult_onset_dystonia,_chorea_or_related_movement_disorder_GA                          19491.0
# Adult_onset_hereditary_spastic_paraplegia_GA                                          20441.0
# Adult_onset_leukodystrophy_GA                                                         19457.0
# Arthrogryposis_GA                                                                     22666.0
# Ataxia_and_cerebellar_anomalies_-_narrow_panel_GA                                     20781.0
# Autism_GA                                                                             20350.0
# Brain_channelopathy_GA                                                                19549.0
# Cerebellar_hypoplasia_GA                                                              21126.0
# Cerebral_vascular_malformations_GA                                                    22225.0
# Childhood_onset_dystonia,_chorea_or_related_movement_disorder_GA                      19505.0
# Childhood_onset_hereditary_spastic_paraplegia_GA                                      19566.0
# Congenital_muscular_dystrophy_GA                                                      19504.0
# Congenital_myaesthenic_syndrome_GA                                                    21003.0
# Congenital_myopathy_GA                                                                20509.0
# Distal_myopathies_GA                                                                  21153.0
# Early_onset_dementia_(encompassing_fronto-temporal_dementia_and_prion_disease)_GA     19549.0
# Early_onset_dystonia_GA                                                               19688.0
# Early_onset_or_syndromic_epilepsy_GA                                                  19001.0
# Familial_dysautonomia_GA                                                              19588.0
# Hereditary_ataxia_GA                                                                  19500.0
# Hereditary_ataxia_with_onset_in_adulthood_GA                                          21722.0
# Hereditary_neuropathy_GA                                                              20392.0
# Hereditary_neuropathy_or_pain_disorder_GA                                             20347.0
# Hereditary_spastic_paraplegia_GA                                                      20497.0
# Holoprosencephaly_-_NOT_chromosomal_GA                                                22411.0
# Hydrocephalus_GA                                                                      22689.0
# Inherited_white_matter_disorders_GA                                                   20414.0
# Intellectual_disability_-_microarray_and_sequencing_GA                                19440.0
# Intracerebral_calcification_disorders_GA                                              20931.0
# Limb_girdle_muscular_dystrophies,_myofibrillar_myopathies_and_distal_myopathies_GA    19526.0
# Malformations_of_cortical_development_GA                                              20345.0
# Neuronal_ceroid_lipofuscinosis_GA                                                     21142.0
# Neurotransmitter_disorders_GA                                                         19509.0
# Paediatric_motor_neuronopathies_GA                                                    21291.0
# Pain_syndromes_GA                                                                     19546.0
# Parkinson_Disease_and_Complex_Parkinsonism_GA                                         19535.0
# Paroxysmal_central_nervous_system_disorders_GA                                        19515.0
# Rhabdomyolysis_and_metabolic_muscle_disorders_GA                                      19488.0
# Skeletal_Muscle_Channelopathies_GA                                                    19739.0
# Structural_basal_ganglia_disorders_GA                                                 19637.0
# White_matter_disorders_and_cerebral_calcification_-_narrow_panel_GA                   19494.0
# Hereditary_systemic_amyloidosis_GA                                                    20574.0
# Rare_genetic_inflammatory_skin_disorders_GA                                           19463.0
# Anophthalmia_or_microphthalmia_GA                                                     19704.0
# Bilateral_congenital_or_childhood_onset_cataracts_GA                                  22703.0
# Corneal_abnormalities_GA                                                              21123.0
# Glaucoma_(developmental)_GA                                                           19732.0
# Infantile_nystagmus_GA                                                                19871.0
# Ocular_and_oculo-cutaneous_albinism_GA                                                22405.0
# Ocular_coloboma_GA                                                                    19526.0
# Optic_neuropathy_GA                                                                   21110.0
# Retinal_disorders_GA                                                                  22523.0
# Atypical_haemolytic_uraemic_syndrome_GA                                               22112.0
# CAKUT_GA                                                                              22761.0
# Cystic_kidney_disease_GA                                                              20494.0
# Extreme_early-onset_hypertension_GA                                                   19559.0
# Nephrocalcinosis_or_nephrolithiasis_GA                                                19712.0
# Polycystic_liver_disease_GA                                                           19444.0
# Proteinuric_renal_disease_GA                                                          19648.0
# Renal_tubulopathies_GA                                                                19695.0
# Tubulointerstitial_kidney_disease_GA                                                  20624.0
# Unexplained_kidney_failure_in_young_people_GA                                         19609.0
# Familial_pulmonary_fibrosis_GA                                                        19806.0
# Pneumothorax_-_familial_GA                                                            22158.0
# Pulmonary_fibrosis_familial_GA                                                        19673.0
# Ehlers_Danlos_syndrome_with_a_likely_monogenic_cause_GA                               19718.0
# Periodic_fever_syndromes_GA                                                           19843.0
# Amelogenesis_imperfecta_GA                                                            19462.0
# Choanal_atresia_GA                                                                    21036.0
# Limb_disorders_GA                                                                     22571.0
# Osteogenesis_imperfecta_GA                                                            19522.0
# Osteopetrosis_GA                                                                      21029.0
# Rare_syndromic_craniosynostosis_or_isolated_multisuture_synostosis_GA                 19474.0
# Stickler_syndrome_GA                                                                  19705.0
# Thoracic_dystrophies_GA                                                               20985.0
# Endocrine_neoplasia_GA                                                                19702.0
# Familial_breast_cancer_GA                                                             22255.0
# Familial_rhabdomyosarcoma_GA                                                          19586.0
# Familial_Tumours_Syndromes_of_the_central_&_peripheral_Nervous_system_GA              19701.0
# Inherited_ovarian_cancer_(without_breast_cancer)_GA                                   22256.0
# Inherited_pancreatic_cancer_GA                                                        22256.0
# Inherited_phaeochromocytoma_and_paraganglioma_GA                                      19579.0
# Inherited_phaeochromocytoma_and_paraganglioma_excluding_NF1_GA                        19655.0
# Inherited_predisposition_to_acute_myeloid_leukaemia_(AML)_GA                          19688.0
# Inherited_renal_cancer_GA                                                             19573.0
# Multiple_endocrine_tumours_GA                                                         19737.0
# Neurofibromatosis_Type_1_GA                                                           22228.0
# dtype: float64

# %% [markdown]
# En base al valor máximo de cada panel, obtenemos cual va a ser la posición de corte del top y del bottom.

# %% [markdown]
# ## Top

# %%
division = [x*threshold_top for x in list(max_valuedisease)] 

max_valuedisease = pd.DataFrame(max_valuedisease)
max_valuedisease["top_ranking"] = division
max_valuedisease.T.iloc[1:]

comparison_df = pd.DataFrame([division] * gene_disease_matrix.loc[:, gene_disease_matrix.columns != "Cluster"].shape[0], columns=max_valuedisease.index)
comparison_df.index = gene_disease_matrix.loc[:, gene_disease_matrix.columns != "Cluster"].index
comparison_df # creamos este dataframe con el valor máximo del %top. Ahora compararemos nuestra tabla con esta (¿la posición 0,0 de glowmatrix es menor que la posición 0.0 de comparation_df?). Así calculamos el % de top. 
# estamos quitando los ceros. 
mask = (gene_disease_matrix.loc[:, gene_disease_matrix.columns != "Cluster"] < comparison_df) & (gene_disease_matrix.loc[:, gene_disease_matrix.columns != "Cluster"] != 0)

n_tops = mask.sum(axis = 1)
n_tops
# Out:
# SYMBOL
# FAAP20     11
# FANCM      15
# POT1       11
# FAAP100    12
# XRCC3      13
#            ..
# MTSS1L      0
# C2orf71     0
# FAM57B      0
# FAM92A      0
# WISP3       0
# Length: 24757, dtype: int64

# %%
d = (mask.loc["SDHA"])

pd.set_option('display.max_rows', d.shape[0]+1)
print(d)
# Out:
# Colorectal_cancer_pertinent_cancer_susceptibility_GA                                  False
# Head_and_neck_cancer_pertinent_cancer_susceptibility_GA                               False
# Neuroendocrine_cancer_pertinent_cancer_susceptibility_GA                              False
# Renal_cancer_pertinent_cancer_susceptibility_GA                                        True
# Arrhythmogenic_right_ventricular_cardiomyopathy_GA                                    False
# ClinGen_Familial_thoracic_aortic_aneurysm_and_aortic_dissection_GA                    False
# Dilated_Cardiomyopathy_and_conduction_defects_GA                                      False
# Familial_cerebral_small_vessel_disease_GA                                             False
# Familial_non_syndromic_congenital_heart_disease_GA                                    False
# Hypertrophic_cardiomyopathy_GA                                                        False
# Long_QT_syndrome_GA                                                                   False
# Primary_lymphoedema_GA                                                                False
# Progressive_cardiac_conduction_disease_GA                                             False
# Pulmonary_arterial_hypertension_GA                                                    False
# Vascular_skin_disorders_GA                                                            False
# Bardet_Biedl_syndrome_GA                                                              False
# Neurological_ciliopathies_GA                                                          False
# Primary_ciliary_disorders_GA                                                          False
# Rare_multisystem_ciliopathy_disorders_GA                                              False
# Renal_ciliopathies_GA                                                                 False
# Respiratory_ciliopathies_including_non-CF_bronchiectasis_GA                           False
# Skeletal_ciliopathies_GA                                                              False
# Autosomal_recessive_congenital_ichthyosis_GA                                          False
# Cutaneous_photosensitivity_with_a_likely_genetic_cause_GA                              True
# Ectodermal_dysplasia_without_a_known_gene_mutation_GA                                 False
# Epidermolysis_bullosa_GA                                                              False
# Non-syndromic_hypotrichosis_GA                                                        False
# Palmoplantar_keratoderma_and_erythrokeratodermas_GA                                   False
# Mosaic_skin_disorders_-_deep_sequencing_GA                                            False
# Palmoplantar_keratodermas_GA                                                          False
# Pigmentary_skin_disorders_GA                                                          False
# Primary_immunodeficiency_or_monogenic_inflammatory_bowel_disease_GA                   False
# Clefting_GA                                                                           False
# Fetal_anomalies_GA                                                                    False
# Fetal_hydrops_GA                                                                      False
# Laterality_disorders_and_isomerism_GA                                                 False
# Radial_dysplasia_GA                                                                   False
# RASopathies_GA                                                                        False
# Severe_microcephaly_GA                                                                False
# VACTERL-like_phenotypes_GA                                                            False
# Vici_Syndrome_and_other_autophagy_disorders_GA                                        False
# Xeroderma_pigmentosum,_Trichothiodystrophy_or_Cockayne_syndrome_GA                    False
# Congenital_adrenal_hypoplasia_GA                                                      False
# Congenital_hyperinsulinism_GA                                                         False
# Congenital_hypothyroidism_GA                                                          False
# Diabetes_with_additional_phenotypes_suggestive_of_a_monogenic_aetiology_GA            False
# Disorders_of_sex_development_GA                                                       False
# Familial_diabetes_GA                                                                  False
# Familial_hyperparathyroidism_or_hypocalciuric_hypercalcaemia_GA                       False
# Hypogonadotropic_hypogonadism_(GMS)_GA                                                False
# Insulin_resistance_(including_lipodystrophy)_GA                                       False
# IUGR_and_IGF_abnormalities_GA                                                         False
# Monogenic_diabetes_GA                                                                 False
# Neonatal_diabetes_GA                                                                  False
# Pituitary_hormone_deficiency_GA                                                       False
# Primary_ovarian_insufficiency_GA                                                      False
# Severe_early-onset_obesity_GA                                                         False
# Cholestasis_GA                                                                        False
# Ductal_plate_malformation_GA                                                          False
# Familial_Hirschsprung_Disease_GA                                                      False
# Gastrointestinal_epithelial_barrier_disorders_GA                                      False
# Gastrointestinal_neuromuscular_disorders_GA                                           False
# Infantile_enterocolitis_&_monogenic_inflammatory_bowel_disease_GA                     False
# Intestinal_failure_or_congenital_diarrhoea_GA                                         False
# Neonatal_cholestasis_GA                                                               False
# Non-syndromic_familial_congenital_anorectal_malformations_GA                          False
# Paediatric_pseudo-obstruction_syndrome_GA                                             False
# Beckwith-Wiedemann_syndrome_(BWS)_and_other_congenital_overgrowth_disorders_GA        False
# Growth_failure_in_early_childhood_GA                                                  False
# Inherited_bleeding_disorders_GA                                                       False
# Autoinflammatory_disorders_GA                                                         False
# Bleeding_and_platelet_disorders_GA                                                    False
# Confirmed_Fanconi_anaemia_or_Bloom_syndrome_GA                                        False
# Cytopenia_-_NOT_Fanconi_anaemia_GA                                                    False
# Cytopenias_and_congenital_anaemias_GA                                                 False
# Hereditary_Erythrocytosis_GA                                                          False
# Rare_anaemia_GA                                                                       False
# Thrombophilia_with_a_likely_monogenic_cause_GA                                        False
# Corneal_dystrophy_GA                                                                  False
# Deafness_and_congenital_structural_abnormalities_GA                                   False
# Monogenic_hearing_loss_GA                                                             False
# Congenital_disorders_of_glycosylation_GA                                              False
# Hyperammonaemia_GA                                                                     True
# Hypophosphataemia_or_rickets_GA                                                       False
# Iron_metabolism_disorders_-_NOT_common_HFE_mutations_GA                               False
# Ketotic_hypoglycaemia_GA                                                              False
# Mitochondrial_disorder_with_complex_I_deficiency_GA                                    True
# Mitochondrial_disorder_with_complex_III_deficiency_GA                                  True
# Mitochondrial_disorder_with_complex_IV_deficiency_GA                                   True
# Mitochondrial_disorder_with_complex_V_deficiency_GA                                   False
# Mitochondrial_DNA_maintenance_disorder_GA                                              True
# Mucopolysaccharideosis,_Gaucher,_Fabry_GA                                             False
# Peroxisomal_disorders_GA                                                              False
# Pyruvate_dehydrogenase_(PDH)_deficiency_GA                                             True
# Glycogen_storage_disease_GA                                                           False
# Acute_rhabdomyolysis_GA                                                                True
# Adult_onset_dystonia,_chorea_or_related_movement_disorder_GA                          False
# Adult_onset_hereditary_spastic_paraplegia_GA                                          False
# Adult_onset_leukodystrophy_GA                                                         False
# Arthrogryposis_GA                                                                     False
# Ataxia_and_cerebellar_anomalies_-_narrow_panel_GA                                     False
# Autism_GA                                                                             False
# Brain_channelopathy_GA                                                                False
# Cerebellar_hypoplasia_GA                                                              False
# Cerebral_vascular_malformations_GA                                                    False
# Childhood_onset_dystonia,_chorea_or_related_movement_disorder_GA                       True
# Childhood_onset_hereditary_spastic_paraplegia_GA                                       True
# Congenital_muscular_dystrophy_GA                                                      False
# Congenital_myaesthenic_syndrome_GA                                                    False
# Congenital_myopathy_GA                                                                False
# Distal_myopathies_GA                                                                  False
# Early_onset_dementia_(encompassing_fronto-temporal_dementia_and_prion_disease)_GA     False
# Early_onset_dystonia_GA                                                               False
# Early_onset_or_syndromic_epilepsy_GA                                                  False
# Familial_dysautonomia_GA                                                              False
# Hereditary_ataxia_GA                                                                  False
# Hereditary_ataxia_with_onset_in_adulthood_GA                                          False
# Hereditary_neuropathy_GA                                                               True
# Hereditary_neuropathy_or_pain_disorder_GA                                              True
# Hereditary_spastic_paraplegia_GA                                                      False
# Holoprosencephaly_-_NOT_chromosomal_GA                                                False
# Hydrocephalus_GA                                                                      False
# Inherited_white_matter_disorders_GA                                                   False
# Intellectual_disability_-_microarray_and_sequencing_GA                                False
# Intracerebral_calcification_disorders_GA                                              False
# Limb_girdle_muscular_dystrophies,_myofibrillar_myopathies_and_distal_myopathies_GA    False
# Malformations_of_cortical_development_GA                                              False
# Neuronal_ceroid_lipofuscinosis_GA                                                     False
# Neurotransmitter_disorders_GA                                                         False
# Paediatric_motor_neuronopathies_GA                                                    False
# Pain_syndromes_GA                                                                     False
# Parkinson_Disease_and_Complex_Parkinsonism_GA                                         False
# Paroxysmal_central_nervous_system_disorders_GA                                        False
# Rhabdomyolysis_and_metabolic_muscle_disorders_GA                                       True
# Skeletal_Muscle_Channelopathies_GA                                                    False
# Structural_basal_ganglia_disorders_GA                                                 False
# White_matter_disorders_and_cerebral_calcification_-_narrow_panel_GA                   False
# Hereditary_systemic_amyloidosis_GA                                                    False
# Rare_genetic_inflammatory_skin_disorders_GA                                           False
# Anophthalmia_or_microphthalmia_GA                                                     False
# Bilateral_congenital_or_childhood_onset_cataracts_GA                                  False
# Corneal_abnormalities_GA                                                              False
# Glaucoma_(developmental)_GA                                                           False
# Infantile_nystagmus_GA                                                                False
# Ocular_and_oculo-cutaneous_albinism_GA                                                False
# Ocular_coloboma_GA                                                                    False
# Optic_neuropathy_GA                                                                    True
# Retinal_disorders_GA                                                                  False
# Atypical_haemolytic_uraemic_syndrome_GA                                               False
# CAKUT_GA                                                                              False
# Cystic_kidney_disease_GA                                                              False
# Extreme_early-onset_hypertension_GA                                                   False
# Nephrocalcinosis_or_nephrolithiasis_GA                                                False
# Polycystic_liver_disease_GA                                                           False
# Proteinuric_renal_disease_GA                                                          False
# Renal_tubulopathies_GA                                                                False
# Tubulointerstitial_kidney_disease_GA                                                  False
# Unexplained_kidney_failure_in_young_people_GA                                         False
# Familial_pulmonary_fibrosis_GA                                                        False
# Pneumothorax_-_familial_GA                                                            False
# Pulmonary_fibrosis_familial_GA                                                        False
# Ehlers_Danlos_syndrome_with_a_likely_monogenic_cause_GA                               False
# Periodic_fever_syndromes_GA                                                           False
# Amelogenesis_imperfecta_GA                                                            False
# Choanal_atresia_GA                                                                    False
# Limb_disorders_GA                                                                     False
# Osteogenesis_imperfecta_GA                                                            False
# Osteopetrosis_GA                                                                      False
# Rare_syndromic_craniosynostosis_or_isolated_multisuture_synostosis_GA                 False
# Stickler_syndrome_GA                                                                  False
# Thoracic_dystrophies_GA                                                               False
# Endocrine_neoplasia_GA                                                                False
# Familial_breast_cancer_GA                                                             False
# Familial_rhabdomyosarcoma_GA                                                          False
# Familial_Tumours_Syndromes_of_the_central_&_peripheral_Nervous_system_GA              False
# Inherited_ovarian_cancer_(without_breast_cancer)_GA                                   False
# Inherited_pancreatic_cancer_GA                                                        False
# Inherited_phaeochromocytoma_and_paraganglioma_GA                                      False
# Inherited_phaeochromocytoma_and_paraganglioma_excluding_NF1_GA                        False
# Inherited_predisposition_to_acute_myeloid_leukaemia_(AML)_GA                          False
# Inherited_renal_cancer_GA                                                              True
# Multiple_endocrine_tumours_GA                                                          True
# Neurofibromatosis_Type_1_GA                                                           False
# Name: SDHA, dtype: bool

# %% [markdown]
# ## Bottom

# %%
division_bottom=[x*threshold_bottom for x in list(max_valuedisease[0])] 

max_valuedisease = pd.DataFrame(max_valuedisease)
max_valuedisease["bottom_ranking"] = division_bottom
max_valuedisease.T.iloc[1:]


comparison_bottom_df = pd.DataFrame([division_bottom] * gene_disease_matrix.loc[:, gene_disease_matrix.columns != "Cluster"].shape[0], columns=max_valuedisease.index)
comparison_bottom_df.index = gene_disease_matrix.loc[:, gene_disease_matrix.columns != "Cluster"].index
comparison_bottom_df # creamos este dataframe con el valor máximo del %top. Ahora compararemos nuestra tabla con esta (¿la posición 0,0 de glowmatrix es menor que la posición 0.0 de comparation_df?). Así calculamos el % de top. 

mask_bottom = (gene_disease_matrix.loc[:, gene_disease_matrix.columns != "Cluster"] > comparison_bottom_df) & (gene_disease_matrix.loc[:, gene_disease_matrix.columns != "Cluster"] != 0)

n_bottom = mask_bottom.sum(axis = 1)
n_bottom
# Out:
# SYMBOL
# FAAP20      92
# FANCM        0
# POT1        16
# FAAP100     72
# XRCC3        0
#           ...
# MTSS1L     182
# C2orf71    182
# FAM57B     182
# FAM92A     182
# WISP3      183
# Length: 24757, dtype: int64

# %% [markdown]
# ## Número de Top y Bottom de cada gen:

# %%
ranking_n = pd.DataFrame(
    {'n_top': n_tops,
     'n_bottom': n_bottom
    })

ranking_n
# Out:
#          n_top  n_bottom
# SYMBOL
# FAAP20      11        92
# FANCM       15         0
# POT1        11        16
# FAAP100     12        72
# XRCC3       13         0
# ...        ...       ...
# MTSS1L       0       182
# C2orf71      0       182
# FAM57B       0       182
# FAM92A       0       182
# WISP3        0       183
#
# [24757 rows x 2 columns]

# %%
#ranking_n.to_csv(str("/home/yolanda/tblab/yolanda/GLOWgenes/panelAPP/revision/specific_genes/n_top_"+ str(threshold_top) + "_bottom_"+str(threshold_bottom) +".csv"), header=True)

# %% [markdown]
# Vamos a seleccionar los que solo tienen un top y están en el bottom en el 90% de sus paneles.

# %%
top_1=ranking_n.query('n_top == 1 and n_bottom > 164' )  ## 164 sería el número de paneles (183) por 0.9 (es decir, bottom en el 90% de los paneles)
top_1
# Out:
#             n_top  n_bottom
# SYMBOL
# C6ORF132        1       179
# MIR505          1       167
# IGL             1       166
# STBD1           1       166
# STMND1          1       167
# FAM24A          1       172
# PRR27           1       168
# IQCF6           1       171
# C1ORF158        1       168
# C4ORF36         1       171
# OR5F1           1       173
# OR1N2           1       172
# SLC22A18AS      1       168
# CCDC166         1       176
# OR5T2           1       180
# SPATA31E1       1       169
# KRTAP22-1       1       170
# SKP1P2          1       178
# RNF224          1       169
# OR52D1          1       168
# OR5T3           1       181
# CFAP99          1       171
# MYMX            1       179
# SNHG22          1       182
# EGFR-AS1        1       182
# SLC9A3-AS1      1       181

# %% [markdown]
# Obtenemos 192 genes.

# %%
gene_disease_matrix
#for r in gene_disease_matrix.loc[top_1.index].shape[0]:
# Out:
#          Colorectal_cancer_pertinent_cancer_susceptibility_GA  \
# SYMBOL
# FAAP20                                              5773.0
# FANCM                                                 64.0
# POT1                                                 413.0
# FAAP100                                             1559.0
# XRCC3                                                107.0
# ...                                                    ...
# MTSS1L                                             19557.0
# C2orf71                                            19557.0
# FAM57B                                             19557.0
# FAM92A                                             19557.0
# WISP3                                              19557.0
#
#          Head_and_neck_cancer_pertinent_cancer_susceptibility_GA  \
# SYMBOL
# FAAP20                                                 4.0
# FANCM                                                  0.0
# POT1                                                 394.0
# FAAP100                                                1.0
# XRCC3                                                 32.0
# ...                                                    ...
# MTSS1L                                             22726.0
# C2orf71                                            22726.0
# FAM57B                                             22726.0
# FAM92A                                             22726.0
# WISP3                                              22726.0
#
#          Neuroendocrine_cancer_pertinent_cancer_susceptibility_GA  \
# SYMBOL
# FAAP20                                             13424.0
# FANCM                                               6109.0
# POT1                                                6885.0
# FAAP100                                            10504.0
# XRCC3                                               2606.0
# ...                                                    ...
# MTSS1L                                             19661.0
# C2orf71                                            19661.0
# FAM57B                                             19661.0
# FAM92A                                             19661.0
# WISP3                                              19661.0
#
#          Renal_cancer_pertinent_cancer_susceptibility_GA  \
# SYMBOL
# FAAP20                                            5967.0
# FANCM                                              579.0
# POT1                                              2316.0
# FAAP100                                           1392.0
# XRCC3                                              566.0
# ...                                                  ...
# MTSS1L                                           19570.0
# C2orf71                                          19570.0
# FAM57B                                           19570.0
# FAM92A                                           19570.0
# WISP3                                            19570.0
#
#          Arrhythmogenic_right_ventricular_cardiomyopathy_GA  \
# SYMBOL
# FAAP20                                             15627.0
# FANCM                                               3181.0
# POT1                                                1846.0
# FAAP100                                            13018.0
# XRCC3                                               5914.0
# ...                                                    ...
# MTSS1L                                             22270.0
# C2orf71                                            22270.0
# FAM57B                                             22270.0
# FAM92A                                             22270.0
# WISP3                                              22270.0
#
#          ClinGen_Familial_thoracic_aortic_aneurysm_and_aortic_dissection_GA  \
# SYMBOL
# FAAP20                                             17947.0
# FANCM                                               3460.0
# POT1                                               15023.0
# FAAP100                                            16063.0
# XRCC3                                               5296.0
# ...                                                    ...
# MTSS1L                                             22353.0
# C2orf71                                            22353.0
# FAM57B                                             22353.0
# FAM92A                                             22353.0
# WISP3                                              22353.0
#
#          Dilated_Cardiomyopathy_and_conduction_defects_GA  \
# SYMBOL
# FAAP20                                            16494.0
# FANCM                                              3242.0
# POT1                                               6605.0
# FAAP100                                           17750.0
# XRCC3                                             10028.0
# ...                                                   ...
# MTSS1L                                            20524.0
# C2orf71                                           20524.0
# FAM57B                                            20524.0
# FAM92A                                            20524.0
# WISP3                                             20524.0
#
#          Familial_cerebral_small_vessel_disease_GA  \
# SYMBOL
# FAAP20                                     16854.0
# FANCM                                       7658.0
# POT1                                       13689.0
# FAAP100                                    15239.0
# XRCC3                                       4564.0
# ...                                            ...
# MTSS1L                                     19592.0
# C2orf71                                    19592.0
# FAM57B                                     19592.0
# FAM92A                                     19592.0
# WISP3                                      19592.0
#
#          Familial_non_syndromic_congenital_heart_disease_GA  \
# SYMBOL
# FAAP20                                             15375.0
# FANCM                                               1238.0
# POT1                                               12507.0
# FAAP100                                             9291.0
# XRCC3                                               6325.0
# ...                                                    ...
# MTSS1L                                             19673.0
# C2orf71                                            19673.0
# FAM57B                                             19673.0
# FAM92A                                             19673.0
# WISP3                                              19673.0
#
#          Hypertrophic_cardiomyopathy_GA  ...  Familial_rhabdomyosarcoma_GA  \
# SYMBOL                                   ...
# FAAP20                          17637.0  ...                        5818.0
# FANCM                           11642.0  ...                         143.0
# POT1                            14375.0  ...                         943.0
# FAAP100                         17731.0  ...                        2797.0
# XRCC3                            7421.0  ...                         219.0
# ...                                 ...  ...                           ...
# MTSS1L                          21736.0  ...                       19586.0
# C2orf71                         21736.0  ...                       19586.0
# FAM57B                          21736.0  ...                       19586.0
# FAM92A                          21736.0  ...                       19586.0
# WISP3                           21736.0  ...                       19586.0
#
#          Familial_Tumours_Syndromes_of_the_central_&_peripheral_Nervous_system_GA  \
# SYMBOL
# FAAP20                                              8198.0
# FANCM                                                189.0
# POT1                                                4015.0
# FAAP100                                             2451.0
# XRCC3                                                255.0
# ...                                                    ...
# MTSS1L                                             19701.0
# C2orf71                                            19701.0
# FAM57B                                             19701.0
# FAM92A                                             19701.0
# WISP3                                              19701.0
#
#          Inherited_ovarian_cancer_(without_breast_cancer)_GA  \
# SYMBOL
# FAAP20                                               564.0
# FANCM                                                 20.0
# POT1                                                 260.0
# FAAP100                                              180.0
# XRCC3                                                  1.0
# ...                                                    ...
# MTSS1L                                             22256.0
# C2orf71                                            22256.0
# FAM57B                                             22256.0
# FAM92A                                             22256.0
# WISP3                                              22256.0
#
#          Inherited_pancreatic_cancer_GA  \
# SYMBOL
# FAAP20                            493.0
# FANCM                              65.0
# POT1                               59.0
# FAAP100                           176.0
# XRCC3                              73.0
# ...                                 ...
# MTSS1L                          22256.0
# C2orf71                         22256.0
# FAM57B                          22256.0
# FAM92A                          22256.0
# WISP3                           22256.0
#
#          Inherited_phaeochromocytoma_and_paraganglioma_GA  \
# SYMBOL
# FAAP20                                            13937.0
# FANCM                                              6115.0
# POT1                                              10747.0
# FAAP100                                           11121.0
# XRCC3                                              1922.0
# ...                                                   ...
# MTSS1L                                            19579.0
# C2orf71                                           19579.0
# FAM57B                                            19579.0
# FAM92A                                            19579.0
# WISP3                                             19579.0
#
#          Inherited_phaeochromocytoma_and_paraganglioma_excluding_NF1_GA  \
# SYMBOL
# FAAP20                                             14695.0
# FANCM                                               7112.0
# POT1                                               11748.0
# FAAP100                                            13732.0
# XRCC3                                               3057.0
# ...                                                    ...
# MTSS1L                                             19655.0
# C2orf71                                            19655.0
# FAM57B                                             19655.0
# FAM92A                                             19655.0
# WISP3                                              19655.0
#
#          Inherited_predisposition_to_acute_myeloid_leukaemia_(AML)_GA  \
# SYMBOL
# FAAP20                                              9970.0
# FANCM                                                316.0
# POT1                                                  13.0
# FAAP100                                              966.0
# XRCC3                                                400.0
# ...                                                    ...
# MTSS1L                                             19688.0
# C2orf71                                            19688.0
# FAM57B                                             19688.0
# FAM92A                                             19688.0
# WISP3                                              19688.0
#
#          Inherited_renal_cancer_GA  Multiple_endocrine_tumours_GA  \
# SYMBOL
# FAAP20                     11996.0                        12204.0
# FANCM                       6501.0                         3855.0
# POT1                         120.0                         4663.0
# FAAP100                    10167.0                        10262.0
# XRCC3                       2021.0                         3741.0
# ...                            ...                            ...
# MTSS1L                     19573.0                        19737.0
# C2orf71                    19573.0                        19737.0
# FAM57B                     19573.0                        19737.0
# FAM92A                     19573.0                        19737.0
# WISP3                      19573.0                        19737.0
#
#          Neurofibromatosis_Type_1_GA
# SYMBOL
# FAAP20                           4.0
# FANCM                            1.0
# POT1                           475.0
# FAAP100                          2.0
# XRCC3                           11.0
# ...                              ...
# MTSS1L                       22228.0
# C2orf71                      22228.0
# FAM57B                       22228.0
# FAM92A                       22228.0
# WISP3                        22228.0
#
# [24757 rows x 183 columns]

# %%
disease_specific_g = {}

for r in top_1.index:
    #print(mask.loc[r,mask.loc[r] == True].index[0]) 
    disease_specific_g[r] = mask.loc[r,mask.loc[r] == True].index[0]

# %%
#mask.loc["GAGE12C"]
max_valuedisease.loc["Ocular_and_oculo-cutaneous_albinism_GA"]
# Out:
# 0                 22405.000
# top_ranking         112.025
# bottom_ranking    16803.750
# Name: Ocular_and_oculo-cutaneous_albinism_GA, dtype: float64

# %%
df_disease_specific_g = pd.DataFrame.from_dict(disease_specific_g, orient = "index", columns=["Panel"])

# %%
df_disease_specific_g
# Out:
#                                                         Panel
# C6ORF132                      Hypophosphataemia_or_rickets_GA
# MIR505              Progressive_cardiac_conduction_disease_GA
# IGL         Infantile_enterocolitis_&_monogenic_inflammato...
# STBD1                             Glycogen_storage_disease_GA
# STMND1      Early_onset_dementia_(encompassing_fronto-temp...
# FAM24A                Atypical_haemolytic_uraemic_syndrome_GA
# PRR27                              Amelogenesis_imperfecta_GA
# IQCF6                 Atypical_haemolytic_uraemic_syndrome_GA
# C1ORF158                         Congenital_hypothyroidism_GA
# C4ORF36                            Amelogenesis_imperfecta_GA
# OR5F1                      Paediatric_motor_neuronopathies_GA
# OR1N2                        Familial_Hirschsprung_Disease_GA
# SLC22A18AS                   Congenital_adrenal_hypoplasia_GA
# CCDC166                                      Osteopetrosis_GA
# OR5T2                  Hypogonadotropic_hypogonadism_(GMS)_GA
# SPATA31E1   Early_onset_dementia_(encompassing_fronto-temp...
# KRTAP22-1                      Non-syndromic_hypotrichosis_GA
# SKP1P2                             Pneumothorax_-_familial_GA
# RNF224                 Nephrocalcinosis_or_nephrolithiasis_GA
# OR52D1                       Familial_Hirschsprung_Disease_GA
# OR5T3                  Hypogonadotropic_hypogonadism_(GMS)_GA
# CFAP99                           Primary_ciliary_disorders_GA
# MYMX                                   Congenital_myopathy_GA
# SNHG22          Intestinal_failure_or_congenital_diarrhoea_GA
# EGFR-AS1        Intestinal_failure_or_congenital_diarrhoea_GA
# SLC9A3-AS1      Intestinal_failure_or_congenital_diarrhoea_GA

# %%
top_1.to_csv(str("/home/yolanda/tblab/yolanda/GLOWgenes/panelAPP/revision/specific_genes/genes_panel_specific_top_"+ str(threshold_top) + "_bottom_"+str(threshold_bottom) +".txt"))
df_disease_specific_g.to_csv(str("/home/yolanda/tblab/yolanda/GLOWgenes/panelAPP/revision/specific_genes/genes_panel_specific_panels_top_"+ str(threshold_top) + "_bottom_"+str(threshold_bottom) +".csv"), header=False)

# %%
import pandas as pd
genes_top1 = pd.read_csv(str("/home/yolanda/tblab/yolanda/GLOWgenes/panelAPP/revision/specific_genes/genes_panel_specific_top_"+ str(threshold_top) + "_bottom_"+str(threshold_bottom) +".txt"),sep = ',') 
genes_top1
genes_panelApp = pd.read_csv('/home/yolanda/tblab/yolanda/GLOWgenes/panelAPP/PANELAPP_ALL_GENES_sep.txt',sep = '\t', header=None) 
#genes_panelApp

# %% [markdown]
# Genes que están en PanelAPP

# %%
[x for x in genes_top1["SYMBOL"] if x in list(genes_panelApp[0]) ]
# Out:
# []

# %% [markdown]
# # Genes específicos de categoría

# %% [markdown]
# Vamos a considerar que para que un gen sea específico de categoría, tiene que estar top en más del 50% de los paneles de su categoría y bottom en el resto.
#
# - De cada gen, obtenemos en qué paneles está en posición top (más arriba del 0.01) y en qué paneles está bottom (por debajo del 0.5). Habrá valores que quedarán en medio.
# - Una vez tenemos esta información, vamos gen por gen, cogiendo los paneles pertenecientes a cada categoría. Si más de la mitad de los paneles son TOPs, consideramos que ese grupo es TOP para ese gen. Si más de la mitad de los paneles están BOTTOM, consideramos que ese panel es BOTTOM para ese gen. Si ni una cosa de la otra, es "MIDDLE".
# - Seleccionamos los genes que tienen una única categoría TOP y tienen más de 10 BOTTOM (que sería más de la mitad de los paneles).

# %%
panel_class
# Out:
#                                                    0  \
# 2                  Cancer Programme+Tumour syndromes
# 4                  Cancer Programme+Tumour syndromes
# 5                  Cancer Programme+Tumour syndromes
# 6                  Cancer Programme+Tumour syndromes
# 9                           Cardiovascular disorders
# 10                          Cardiovascular disorders
# 12                          Cardiovascular disorders
# 13                          Cardiovascular disorders
# 14                          Cardiovascular disorders
# 15                          Cardiovascular disorders
# 16                          Cardiovascular disorders
# 18                          Cardiovascular disorders
# 19                          Cardiovascular disorders
# 20                          Cardiovascular disorders
# 22                          Cardiovascular disorders
# 23                                      Ciliopathies
# 24                                      Ciliopathies
# 26                                      Ciliopathies
# 27                                      Ciliopathies
# 28                                      Ciliopathies
# 29                                      Ciliopathies
# 30                                      Ciliopathies
# 31                          Dermatological disorders
# 32                          Dermatological disorders
# 34                          Dermatological disorders
# 35                          Dermatological disorders
# 38                          Dermatological disorders
# 39                          Dermatological disorders
# 40                          Dermatological disorders
# 41                          Dermatological disorders
# 42                          Dermatological disorders
# 43                          Dermatological disorders
# 44   Dysmorphic and congenital abnormality syndromes
# 45   Dysmorphic and congenital abnormality syndromes
# 46   Dysmorphic and congenital abnormality syndromes
# 47   Dysmorphic and congenital abnormality syndromes
# 48   Dysmorphic and congenital abnormality syndromes
# 49   Dysmorphic and congenital abnormality syndromes
# 50   Dysmorphic and congenital abnormality syndromes
# 51   Dysmorphic and congenital abnormality syndromes
# 52   Dysmorphic and congenital abnormality syndromes
# 53   Dysmorphic and congenital abnormality syndromes
# 54                               Endocrine disorders
# 55                               Endocrine disorders
# 56                               Endocrine disorders
# 57                               Endocrine disorders
# 58                               Endocrine disorders
# 59                               Endocrine disorders
# 60                               Endocrine disorders
# 61                               Endocrine disorders
# 62                               Endocrine disorders
# 63                               Endocrine disorders
# 65                               Endocrine disorders
# 66                               Endocrine disorders
# 67                               Endocrine disorders
# 68                               Endocrine disorders
# 69                               Endocrine disorders
# 70                     Gastroenterological disorders
# 71                     Gastroenterological disorders
# 72                     Gastroenterological disorders
# 73                     Gastroenterological disorders
# 74                     Gastroenterological disorders
# 75                     Gastroenterological disorders
# 76                     Gastroenterological disorders
# 77                     Gastroenterological disorders
# 78                     Gastroenterological disorders
# 79                     Gastroenterological disorders
# 80                                  Growth disorders
# 81                                  Growth disorders
# 82        Haematological and immunological disorders
# 83        Haematological and immunological disorders
# 84        Haematological and immunological disorders
# 85        Haematological and immunological disorders
# 86        Haematological and immunological disorders
# 87        Haematological and immunological disorders
# 88        Haematological and immunological disorders
# 89        Haematological and immunological disorders
# 90        Haematological and immunological disorders
# 91                        Ophthalmological disorders
# 92                         Hearing and ear disorders
# 93                         Hearing and ear disorders
# 94                               Metabolic disorders
# 95                               Metabolic disorders
# 96                               Metabolic disorders
# 97                               Metabolic disorders
# 98                               Metabolic disorders
# 102                              Metabolic disorders
# 103                              Metabolic disorders
# 104                              Metabolic disorders
# 105                              Metabolic disorders
# 106                              Metabolic disorders
# 107                              Metabolic disorders
# 108                              Metabolic disorders
# 109                              Metabolic disorders
# 111                              Metabolic disorders
# 112       Neurology and neurodevelopmental disorders
# 113       Neurology and neurodevelopmental disorders
# 114       Neurology and neurodevelopmental disorders
# 115       Neurology and neurodevelopmental disorders
# 117       Neurology and neurodevelopmental disorders
# 118       Neurology and neurodevelopmental disorders
# 119       Neurology and neurodevelopmental disorders
# 120       Neurology and neurodevelopmental disorders
# 121       Neurology and neurodevelopmental disorders
# 122       Neurology and neurodevelopmental disorders
# 123       Neurology and neurodevelopmental disorders
# 124       Neurology and neurodevelopmental disorders
# 125       Neurology and neurodevelopmental disorders
# 126       Neurology and neurodevelopmental disorders
# 127       Neurology and neurodevelopmental disorders
# 128       Neurology and neurodevelopmental disorders
# 129       Neurology and neurodevelopmental disorders
# 130       Neurology and neurodevelopmental disorders
# 131       Neurology and neurodevelopmental disorders
# 132       Neurology and neurodevelopmental disorders
# 133       Neurology and neurodevelopmental disorders
# 134       Neurology and neurodevelopmental disorders
# 135       Neurology and neurodevelopmental disorders
# 136       Neurology and neurodevelopmental disorders
# 137       Neurology and neurodevelopmental disorders
# 138       Neurology and neurodevelopmental disorders
# 139       Neurology and neurodevelopmental disorders
# 140       Neurology and neurodevelopmental disorders
# 141       Neurology and neurodevelopmental disorders
# 142       Neurology and neurodevelopmental disorders
# 143       Neurology and neurodevelopmental disorders
# 144       Neurology and neurodevelopmental disorders
# 145       Neurology and neurodevelopmental disorders
# 146       Neurology and neurodevelopmental disorders
# 147       Neurology and neurodevelopmental disorders
# 148       Neurology and neurodevelopmental disorders
# 149       Neurology and neurodevelopmental disorders
# 150       Neurology and neurodevelopmental disorders
# 151       Neurology and neurodevelopmental disorders
# 152       Neurology and neurodevelopmental disorders
# 153       Neurology and neurodevelopmental disorders
# 154       Neurology and neurodevelopmental disorders
# 155       Neurology and neurodevelopmental disorders
# 156                         Dermatological disorders
# 159                       Ophthalmological disorders
# 160                       Ophthalmological disorders
# 161                       Ophthalmological disorders
# 162                       Ophthalmological disorders
# 163                       Ophthalmological disorders
# 164                       Ophthalmological disorders
# 165                       Ophthalmological disorders
# 166                       Ophthalmological disorders
# 167                       Ophthalmological disorders
# 168                Renal and urinary tract disorders
# 169                Renal and urinary tract disorders
# 170                Renal and urinary tract disorders
# 171                Renal and urinary tract disorders
# 172                Renal and urinary tract disorders
# 173                Renal and urinary tract disorders
# 174                Renal and urinary tract disorders
# 175                Renal and urinary tract disorders
# 176                Renal and urinary tract disorders
# 177                Renal and urinary tract disorders
# 179                            Respiratory disorders
# 180                            Respiratory disorders
# 181                            Respiratory disorders
# 182                        Rheumatological disorders
# 183                        Rheumatological disorders
# 184                               Skeletal disorders
# 185                               Skeletal disorders
# 186                               Skeletal disorders
# 187                               Skeletal disorders
# 188                               Skeletal disorders
# 189                               Skeletal disorders
# 191                               Skeletal disorders
# 192                               Skeletal disorders
# 195                Cancer Programme+Tumour syndromes
# 196                Cancer Programme+Tumour syndromes
# 197                Cancer Programme+Tumour syndromes
# 198                Cancer Programme+Tumour syndromes
# 201                Cancer Programme+Tumour syndromes
# 202                Cancer Programme+Tumour syndromes
# 203                Cancer Programme+Tumour syndromes
# 204                Cancer Programme+Tumour syndromes
# 205                Cancer Programme+Tumour syndromes
# 206                Cancer Programme+Tumour syndromes
# 207                Cancer Programme+Tumour syndromes
# 208                Cancer Programme+Tumour syndromes
#
#                                                      1
# 2    Colorectal_cancer_pertinent_cancer_susceptibil...
# 4    Head_and_neck_cancer_pertinent_cancer_suscepti...
# 5    Neuroendocrine_cancer_pertinent_cancer_suscept...
# 6      Renal_cancer_pertinent_cancer_susceptibility_GA
# 9    Arrhythmogenic_right_ventricular_cardiomyopath...
# 10   ClinGen_Familial_thoracic_aortic_aneurysm_and_...
# 12    Dilated_Cardiomyopathy_and_conduction_defects_GA
# 13           Familial_cerebral_small_vessel_disease_GA
# 14   Familial_non_syndromic_congenital_heart_diseas...
# 15                      Hypertrophic_cardiomyopathy_GA
# 16                                 Long_QT_syndrome_GA
# 18                              Primary_lymphoedema_GA
# 19           Progressive_cardiac_conduction_disease_GA
# 20                  Pulmonary_arterial_hypertension_GA
# 22                          Vascular_skin_disorders_GA
# 23                            Bardet_Biedl_syndrome_GA
# 24                        Neurological_ciliopathies_GA
# 26                        Primary_ciliary_disorders_GA
# 27            Rare_multisystem_ciliopathy_disorders_GA
# 28                               Renal_ciliopathies_GA
# 29   Respiratory_ciliopathies_including_non-CF_bron...
# 30                            Skeletal_ciliopathies_GA
# 31        Autosomal_recessive_congenital_ichthyosis_GA
# 32   Cutaneous_photosensitivity_with_a_likely_genet...
# 34   Ectodermal_dysplasia_without_a_known_gene_muta...
# 35                            Epidermolysis_bullosa_GA
# 38                      Non-syndromic_hypotrichosis_GA
# 39   Palmoplantar_keratoderma_and_erythrokeratoderm...
# 40          Mosaic_skin_disorders_-_deep_sequencing_GA
# 41                        Palmoplantar_keratodermas_GA
# 42                        Pigmentary_skin_disorders_GA
# 43   Primary_immunodeficiency_or_monogenic_inflamma...
# 44                                         Clefting_GA
# 45                                  Fetal_anomalies_GA
# 46                                    Fetal_hydrops_GA
# 47               Laterality_disorders_and_isomerism_GA
# 48                                 Radial_dysplasia_GA
# 49                                      RASopathies_GA
# 50                              Severe_microcephaly_GA
# 51                          VACTERL-like_phenotypes_GA
# 52      Vici_Syndrome_and_other_autophagy_disorders_GA
# 53   Xeroderma_pigmentosum,_Trichothiodystrophy_or_...
# 54                    Congenital_adrenal_hypoplasia_GA
# 55                       Congenital_hyperinsulinism_GA
# 56                        Congenital_hypothyroidism_GA
# 57   Diabetes_with_additional_phenotypes_suggestive...
# 58                     Disorders_of_sex_development_GA
# 59                                Familial_diabetes_GA
# 60   Familial_hyperparathyroidism_or_hypocalciuric_...
# 61              Hypogonadotropic_hypogonadism_(GMS)_GA
# 62     Insulin_resistance_(including_lipodystrophy)_GA
# 63                       IUGR_and_IGF_abnormalities_GA
# 65                               Monogenic_diabetes_GA
# 66                                Neonatal_diabetes_GA
# 67                     Pituitary_hormone_deficiency_GA
# 68                    Primary_ovarian_insufficiency_GA
# 69                       Severe_early-onset_obesity_GA
# 70                                      Cholestasis_GA
# 71                        Ductal_plate_malformation_GA
# 72                    Familial_Hirschsprung_Disease_GA
# 73    Gastrointestinal_epithelial_barrier_disorders_GA
# 74         Gastrointestinal_neuromuscular_disorders_GA
# 75   Infantile_enterocolitis_&_monogenic_inflammato...
# 76       Intestinal_failure_or_congenital_diarrhoea_GA
# 77                             Neonatal_cholestasis_GA
# 78   Non-syndromic_familial_congenital_anorectal_ma...
# 79           Paediatric_pseudo-obstruction_syndrome_GA
# 80   Beckwith-Wiedemann_syndrome_(BWS)_and_other_co...
# 81                Growth_failure_in_early_childhood_GA
# 82                     Inherited_bleeding_disorders_GA
# 83                       Autoinflammatory_disorders_GA
# 84                  Bleeding_and_platelet_disorders_GA
# 85      Confirmed_Fanconi_anaemia_or_Bloom_syndrome_GA
# 86                  Cytopenia_-_NOT_Fanconi_anaemia_GA
# 87               Cytopenias_and_congenital_anaemias_GA
# 88                        Hereditary_Erythrocytosis_GA
# 89                                     Rare_anaemia_GA
# 90      Thrombophilia_with_a_likely_monogenic_cause_GA
# 91                                Corneal_dystrophy_GA
# 92   Deafness_and_congenital_structural_abnormaliti...
# 93                           Monogenic_hearing_loss_GA
# 94            Congenital_disorders_of_glycosylation_GA
# 95                                  Hyperammonaemia_GA
# 96                     Hypophosphataemia_or_rickets_GA
# 97   Iron_metabolism_disorders_-_NOT_common_HFE_mut...
# 98                            Ketotic_hypoglycaemia_GA
# 102  Mitochondrial_disorder_with_complex_I_deficien...
# 103  Mitochondrial_disorder_with_complex_III_defici...
# 104  Mitochondrial_disorder_with_complex_IV_deficie...
# 105  Mitochondrial_disorder_with_complex_V_deficien...
# 106          Mitochondrial_DNA_maintenance_disorder_GA
# 107          Mucopolysaccharideosis,_Gaucher,_Fabry_GA
# 108                           Peroxisomal_disorders_GA
# 109         Pyruvate_dehydrogenase_(PDH)_deficiency_GA
# 111                        Glycogen_storage_disease_GA
# 112                            Acute_rhabdomyolysis_GA
# 113  Adult_onset_dystonia,_chorea_or_related_moveme...
# 114       Adult_onset_hereditary_spastic_paraplegia_GA
# 115                      Adult_onset_leukodystrophy_GA
# 117                                  Arthrogryposis_GA
# 118  Ataxia_and_cerebellar_anomalies_-_narrow_panel_GA
# 119                                          Autism_GA
# 120                             Brain_channelopathy_GA
# 121                           Cerebellar_hypoplasia_GA
# 122                 Cerebral_vascular_malformations_GA
# 123  Childhood_onset_dystonia,_chorea_or_related_mo...
# 124   Childhood_onset_hereditary_spastic_paraplegia_GA
# 125                   Congenital_muscular_dystrophy_GA
# 126                 Congenital_myaesthenic_syndrome_GA
# 127                             Congenital_myopathy_GA
# 128                               Distal_myopathies_GA
# 129  Early_onset_dementia_(encompassing_fronto-temp...
# 130                            Early_onset_dystonia_GA
# 131               Early_onset_or_syndromic_epilepsy_GA
# 132                           Familial_dysautonomia_GA
# 133                               Hereditary_ataxia_GA
# 134       Hereditary_ataxia_with_onset_in_adulthood_GA
# 135                           Hereditary_neuropathy_GA
# 136          Hereditary_neuropathy_or_pain_disorder_GA
# 137                   Hereditary_spastic_paraplegia_GA
# 138             Holoprosencephaly_-_NOT_chromosomal_GA
# 139                                   Hydrocephalus_GA
# 140                Inherited_white_matter_disorders_GA
# 141  Intellectual_disability_-_microarray_and_seque...
# 142           Intracerebral_calcification_disorders_GA
# 143  Limb_girdle_muscular_dystrophies,_myofibrillar...
# 144           Malformations_of_cortical_development_GA
# 145                  Neuronal_ceroid_lipofuscinosis_GA
# 146                      Neurotransmitter_disorders_GA
# 147                 Paediatric_motor_neuronopathies_GA
# 148                                  Pain_syndromes_GA
# 149      Parkinson_Disease_and_Complex_Parkinsonism_GA
# 150     Paroxysmal_central_nervous_system_disorders_GA
# 151   Rhabdomyolysis_and_metabolic_muscle_disorders_GA
# 152                 Skeletal_Muscle_Channelopathies_GA
# 153              Structural_basal_ganglia_disorders_GA
# 154  White_matter_disorders_and_cerebral_calcificat...
# 155                 Hereditary_systemic_amyloidosis_GA
# 156        Rare_genetic_inflammatory_skin_disorders_GA
# 159                  Anophthalmia_or_microphthalmia_GA
# 160  Bilateral_congenital_or_childhood_onset_catara...
# 161                           Corneal_abnormalities_GA
# 162                        Glaucoma_(developmental)_GA
# 163                             Infantile_nystagmus_GA
# 164             Ocular_and_oculo-cutaneous_albinism_GA
# 165                                 Ocular_coloboma_GA
# 166                                Optic_neuropathy_GA
# 167                               Retinal_disorders_GA
# 168            Atypical_haemolytic_uraemic_syndrome_GA
# 169                                           CAKUT_GA
# 170                           Cystic_kidney_disease_GA
# 171                Extreme_early-onset_hypertension_GA
# 172             Nephrocalcinosis_or_nephrolithiasis_GA
# 173                        Polycystic_liver_disease_GA
# 174                       Proteinuric_renal_disease_GA
# 175                             Renal_tubulopathies_GA
# 176               Tubulointerstitial_kidney_disease_GA
# 177      Unexplained_kidney_failure_in_young_people_GA
# 179                     Familial_pulmonary_fibrosis_GA
# 180                         Pneumothorax_-_familial_GA
# 181                     Pulmonary_fibrosis_familial_GA
# 182  Ehlers_Danlos_syndrome_with_a_likely_monogenic...
# 183                        Periodic_fever_syndromes_GA
# 184                         Amelogenesis_imperfecta_GA
# 185                                 Choanal_atresia_GA
# 186                                  Limb_disorders_GA
# 187                         Osteogenesis_imperfecta_GA
# 188                                   Osteopetrosis_GA
# 189  Rare_syndromic_craniosynostosis_or_isolated_mu...
# 191                               Stickler_syndrome_GA
# 192                            Thoracic_dystrophies_GA
# 195                             Endocrine_neoplasia_GA
# 196                          Familial_breast_cancer_GA
# 197                       Familial_rhabdomyosarcoma_GA
# 198  Familial_Tumours_Syndromes_of_the_central_&_pe...
# 201  Inherited_ovarian_cancer_(without_breast_cance...
# 202                     Inherited_pancreatic_cancer_GA
# 203   Inherited_phaeochromocytoma_and_paraganglioma_GA
# 204  Inherited_phaeochromocytoma_and_paraganglioma_...
# 205  Inherited_predisposition_to_acute_myeloid_leuk...
# 206                          Inherited_renal_cancer_GA
# 207                      Multiple_endocrine_tumours_GA
# 208                        Neurofibromatosis_Type_1_GA

# %%
threshold_top=0.025 # por encima de
threshold_bottom=0.5 # por debajo de 
max_valuedisease=gene_disease_matrix.loc[:, gene_disease_matrix.columns != "Cluster"].max(axis=0) # el valor máximo de cada uno de los paneles.

# %%
class_top_bottom = pd.DataFrame(columns=list(set(panel_class[0])), 
            index = gene_disease_matrix.index)
class_top_bottom
# Out:
#         Cardiovascular disorders Renal and urinary tract disorders  \
# SYMBOL
# FAAP20                       NaN                               NaN
# FANCM                        NaN                               NaN
# POT1                         NaN                               NaN
# FAAP100                      NaN                               NaN
# XRCC3                        NaN                               NaN
# ...                          ...                               ...
# MTSS1L                       NaN                               NaN
# C2orf71                      NaN                               NaN
# FAM57B                       NaN                               NaN
# FAM92A                       NaN                               NaN
# WISP3                        NaN                               NaN
#
#         Respiratory disorders Gastroenterological disorders Ciliopathies  \
# SYMBOL
# FAAP20                    NaN                           NaN          NaN
# FANCM                     NaN                           NaN          NaN
# POT1                      NaN                           NaN          NaN
# FAAP100                   NaN                           NaN          NaN
# XRCC3                     NaN                           NaN          NaN
# ...                       ...                           ...          ...
# MTSS1L                    NaN                           NaN          NaN
# C2orf71                   NaN                           NaN          NaN
# FAM57B                    NaN                           NaN          NaN
# FAM92A                    NaN                           NaN          NaN
# WISP3                     NaN                           NaN          NaN
#
#         Growth disorders Ophthalmological disorders Skeletal disorders  \
# SYMBOL
# FAAP20               NaN                        NaN                NaN
# FANCM                NaN                        NaN                NaN
# POT1                 NaN                        NaN                NaN
# FAAP100              NaN                        NaN                NaN
# XRCC3                NaN                        NaN                NaN
# ...                  ...                        ...                ...
# MTSS1L               NaN                        NaN                NaN
# C2orf71              NaN                        NaN                NaN
# FAM57B               NaN                        NaN                NaN
# FAM92A               NaN                        NaN                NaN
# WISP3                NaN                        NaN                NaN
#
#         Haematological and immunological disorders Rheumatological disorders  \
# SYMBOL
# FAAP20                                         NaN                       NaN
# FANCM                                          NaN                       NaN
# POT1                                           NaN                       NaN
# FAAP100                                        NaN                       NaN
# XRCC3                                          NaN                       NaN
# ...                                            ...                       ...
# MTSS1L                                         NaN                       NaN
# C2orf71                                        NaN                       NaN
# FAM57B                                         NaN                       NaN
# FAM92A                                         NaN                       NaN
# WISP3                                          NaN                       NaN
#
#         Hearing and ear disorders Dermatological disorders  \
# SYMBOL
# FAAP20                        NaN                      NaN
# FANCM                         NaN                      NaN
# POT1                          NaN                      NaN
# FAAP100                       NaN                      NaN
# XRCC3                         NaN                      NaN
# ...                           ...                      ...
# MTSS1L                        NaN                      NaN
# C2orf71                       NaN                      NaN
# FAM57B                        NaN                      NaN
# FAM92A                        NaN                      NaN
# WISP3                         NaN                      NaN
#
#         Cancer Programme+Tumour syndromes  \
# SYMBOL
# FAAP20                                NaN
# FANCM                                 NaN
# POT1                                  NaN
# FAAP100                               NaN
# XRCC3                                 NaN
# ...                                   ...
# MTSS1L                                NaN
# C2orf71                               NaN
# FAM57B                                NaN
# FAM92A                                NaN
# WISP3                                 NaN
#
#         Dysmorphic and congenital abnormality syndromes  \
# SYMBOL
# FAAP20                                              NaN
# FANCM                                               NaN
# POT1                                                NaN
# FAAP100                                             NaN
# XRCC3                                               NaN
# ...                                                 ...
# MTSS1L                                              NaN
# C2orf71                                             NaN
# FAM57B                                              NaN
# FAM92A                                              NaN
# WISP3                                               NaN
#
#         Neurology and neurodevelopmental disorders Endocrine disorders  \
# SYMBOL
# FAAP20                                         NaN                 NaN
# FANCM                                          NaN                 NaN
# POT1                                           NaN                 NaN
# FAAP100                                        NaN                 NaN
# XRCC3                                          NaN                 NaN
# ...                                            ...                 ...
# MTSS1L                                         NaN                 NaN
# C2orf71                                        NaN                 NaN
# FAM57B                                         NaN                 NaN
# FAM92A                                         NaN                 NaN
# WISP3                                          NaN                 NaN
#
#         Metabolic disorders
# SYMBOL
# FAAP20                  NaN
# FANCM                   NaN
# POT1                    NaN
# FAAP100                 NaN
# XRCC3                   NaN
# ...                     ...
# MTSS1L                  NaN
# C2orf71                 NaN
# FAM57B                  NaN
# FAM92A                  NaN
# WISP3                   NaN
#
# [24757 rows x 17 columns]

# %%
division = [x*threshold_top for x in list(max_valuedisease)] 

max_valuedisease = pd.DataFrame(max_valuedisease)
max_valuedisease["top_ranking"] = division
max_valuedisease.T.iloc[1:]

comparison_df = pd.DataFrame([division] * gene_disease_matrix.loc[:, gene_disease_matrix.columns != "Cluster"].shape[0], columns=max_valuedisease.index)
comparison_df.index = gene_disease_matrix.loc[:, gene_disease_matrix.columns != "Cluster"].index
comparison_df # creamos este dataframe con el valor máximo del %top. Ahora compararemos nuestra tabla con esta (¿la posición 0,0 de glowmatrix es menor que la posición 0.0 de comparation_df?). Así calculamos el % de top. 

mask = (gene_disease_matrix.loc[:, gene_disease_matrix.columns != "Cluster"] < comparison_df) & (gene_disease_matrix.loc[:, gene_disease_matrix.columns != "Cluster"] != 0)


top_bottom = mask
top_bottom
# Out:
#          Colorectal_cancer_pertinent_cancer_susceptibility_GA  \
# SYMBOL
# FAAP20                                               False
# FANCM                                                 True
# POT1                                                  True
# FAAP100                                              False
# XRCC3                                                 True
# ...                                                    ...
# MTSS1L                                               False
# C2orf71                                              False
# FAM57B                                               False
# FAM92A                                               False
# WISP3                                                False
#
#          Head_and_neck_cancer_pertinent_cancer_susceptibility_GA  \
# SYMBOL
# FAAP20                                                True
# FANCM                                                False
# POT1                                                  True
# FAAP100                                               True
# XRCC3                                                 True
# ...                                                    ...
# MTSS1L                                               False
# C2orf71                                              False
# FAM57B                                               False
# FAM92A                                               False
# WISP3                                                False
#
#          Neuroendocrine_cancer_pertinent_cancer_susceptibility_GA  \
# SYMBOL
# FAAP20                                               False
# FANCM                                                False
# POT1                                                 False
# FAAP100                                              False
# XRCC3                                                False
# ...                                                    ...
# MTSS1L                                               False
# C2orf71                                              False
# FAM57B                                               False
# FAM92A                                               False
# WISP3                                                False
#
#          Renal_cancer_pertinent_cancer_susceptibility_GA  \
# SYMBOL
# FAAP20                                             False
# FANCM                                              False
# POT1                                               False
# FAAP100                                            False
# XRCC3                                              False
# ...                                                  ...
# MTSS1L                                             False
# C2orf71                                            False
# FAM57B                                             False
# FAM92A                                             False
# WISP3                                              False
#
#          Arrhythmogenic_right_ventricular_cardiomyopathy_GA  \
# SYMBOL
# FAAP20                                               False
# FANCM                                                False
# POT1                                                 False
# FAAP100                                              False
# XRCC3                                                False
# ...                                                    ...
# MTSS1L                                               False
# C2orf71                                              False
# FAM57B                                               False
# FAM92A                                               False
# WISP3                                                False
#
#          ClinGen_Familial_thoracic_aortic_aneurysm_and_aortic_dissection_GA  \
# SYMBOL
# FAAP20                                               False
# FANCM                                                False
# POT1                                                 False
# FAAP100                                              False
# XRCC3                                                False
# ...                                                    ...
# MTSS1L                                               False
# C2orf71                                              False
# FAM57B                                               False
# FAM92A                                               False
# WISP3                                                False
#
#          Dilated_Cardiomyopathy_and_conduction_defects_GA  \
# SYMBOL
# FAAP20                                              False
# FANCM                                               False
# POT1                                                False
# FAAP100                                             False
# XRCC3                                               False
# ...                                                   ...
# MTSS1L                                              False
# C2orf71                                             False
# FAM57B                                              False
# FAM92A                                              False
# WISP3                                               False
#
#          Familial_cerebral_small_vessel_disease_GA  \
# SYMBOL
# FAAP20                                       False
# FANCM                                        False
# POT1                                         False
# FAAP100                                      False
# XRCC3                                        False
# ...                                            ...
# MTSS1L                                       False
# C2orf71                                      False
# FAM57B                                       False
# FAM92A                                       False
# WISP3                                        False
#
#          Familial_non_syndromic_congenital_heart_disease_GA  \
# SYMBOL
# FAAP20                                               False
# FANCM                                                False
# POT1                                                 False
# FAAP100                                              False
# XRCC3                                                False
# ...                                                    ...
# MTSS1L                                               False
# C2orf71                                              False
# FAM57B                                               False
# FAM92A                                               False
# WISP3                                                False
#
#          Hypertrophic_cardiomyopathy_GA  ...  Familial_rhabdomyosarcoma_GA  \
# SYMBOL                                   ...
# FAAP20                            False  ...                         False
# FANCM                             False  ...                          True
# POT1                              False  ...                         False
# FAAP100                           False  ...                         False
# XRCC3                             False  ...                          True
# ...                                 ...  ...                           ...
# MTSS1L                            False  ...                         False
# C2orf71                           False  ...                         False
# FAM57B                            False  ...                         False
# FAM92A                            False  ...                         False
# WISP3                             False  ...                         False
#
#          Familial_Tumours_Syndromes_of_the_central_&_peripheral_Nervous_system_GA  \
# SYMBOL
# FAAP20                                               False
# FANCM                                                 True
# POT1                                                 False
# FAAP100                                              False
# XRCC3                                                 True
# ...                                                    ...
# MTSS1L                                               False
# C2orf71                                              False
# FAM57B                                               False
# FAM92A                                               False
# WISP3                                                False
#
#          Inherited_ovarian_cancer_(without_breast_cancer)_GA  \
# SYMBOL
# FAAP20                                               False
# FANCM                                                 True
# POT1                                                  True
# FAAP100                                               True
# XRCC3                                                 True
# ...                                                    ...
# MTSS1L                                               False
# C2orf71                                              False
# FAM57B                                               False
# FAM92A                                               False
# WISP3                                                False
#
#          Inherited_pancreatic_cancer_GA  \
# SYMBOL
# FAAP20                             True
# FANCM                              True
# POT1                               True
# FAAP100                            True
# XRCC3                              True
# ...                                 ...
# MTSS1L                            False
# C2orf71                           False
# FAM57B                            False
# FAM92A                            False
# WISP3                             False
#
#          Inherited_phaeochromocytoma_and_paraganglioma_GA  \
# SYMBOL
# FAAP20                                              False
# FANCM                                               False
# POT1                                                False
# FAAP100                                             False
# XRCC3                                               False
# ...                                                   ...
# MTSS1L                                              False
# C2orf71                                             False
# FAM57B                                              False
# FAM92A                                              False
# WISP3                                               False
#
#          Inherited_phaeochromocytoma_and_paraganglioma_excluding_NF1_GA  \
# SYMBOL
# FAAP20                                               False
# FANCM                                                False
# POT1                                                 False
# FAAP100                                              False
# XRCC3                                                False
# ...                                                    ...
# MTSS1L                                               False
# C2orf71                                              False
# FAM57B                                               False
# FAM92A                                               False
# WISP3                                                False
#
#          Inherited_predisposition_to_acute_myeloid_leukaemia_(AML)_GA  \
# SYMBOL
# FAAP20                                               False
# FANCM                                                 True
# POT1                                                  True
# FAAP100                                              False
# XRCC3                                                 True
# ...                                                    ...
# MTSS1L                                               False
# C2orf71                                              False
# FAM57B                                               False
# FAM92A                                               False
# WISP3                                                False
#
#          Inherited_renal_cancer_GA  Multiple_endocrine_tumours_GA  \
# SYMBOL
# FAAP20                       False                          False
# FANCM                        False                          False
# POT1                          True                          False
# FAAP100                      False                          False
# XRCC3                        False                          False
# ...                            ...                            ...
# MTSS1L                       False                          False
# C2orf71                      False                          False
# FAM57B                       False                          False
# FAM92A                       False                          False
# WISP3                        False                          False
#
#          Neurofibromatosis_Type_1_GA
# SYMBOL
# FAAP20                          True
# FANCM                           True
# POT1                            True
# FAAP100                         True
# XRCC3                           True
# ...                              ...
# MTSS1L                         False
# C2orf71                        False
# FAM57B                         False
# FAM92A                         False
# WISP3                          False
#
# [24757 rows x 183 columns]

# %%
max_valuedisease
# Out:
#                                                           0  top_ranking
# Colorectal_cancer_pertinent_cancer_susceptibili...  19557.0      488.925
# Head_and_neck_cancer_pertinent_cancer_susceptib...  22726.0      568.150
# Neuroendocrine_cancer_pertinent_cancer_suscepti...  19661.0      491.525
# Renal_cancer_pertinent_cancer_susceptibility_GA     19570.0      489.250
# Arrhythmogenic_right_ventricular_cardiomyopathy_GA  22270.0      556.750
# ClinGen_Familial_thoracic_aortic_aneurysm_and_a...  22353.0      558.825
# Dilated_Cardiomyopathy_and_conduction_defects_GA    20524.0      513.100
# Familial_cerebral_small_vessel_disease_GA           19592.0      489.800
# Familial_non_syndromic_congenital_heart_disease_GA  19673.0      491.825
# Hypertrophic_cardiomyopathy_GA                      21736.0      543.400
# Long_QT_syndrome_GA                                 22247.0      556.175
# Primary_lymphoedema_GA                              19492.0      487.300
# Progressive_cardiac_conduction_disease_GA           22238.0      555.950
# Pulmonary_arterial_hypertension_GA                  19514.0      487.850
# Vascular_skin_disorders_GA                          19544.0      488.600
# Bardet_Biedl_syndrome_GA                            21007.0      525.175
# Neurological_ciliopathies_GA                        22196.0      554.900
# Primary_ciliary_disorders_GA                        22312.0      557.800
# Rare_multisystem_ciliopathy_disorders_GA            20938.0      523.450
# Renal_ciliopathies_GA                               21738.0      543.450
# Respiratory_ciliopathies_including_non-CF_bronc...  21142.0      528.550
# Skeletal_ciliopathies_GA                            22213.0      555.325
# Autosomal_recessive_congenital_ichthyosis_GA        19497.0      487.425
# Cutaneous_photosensitivity_with_a_likely_geneti...  19511.0      487.775
# Ectodermal_dysplasia_without_a_known_gene_mutat...  19688.0      492.200
# Epidermolysis_bullosa_GA                            21793.0      544.825
# Non-syndromic_hypotrichosis_GA                      20531.0      513.275
# Palmoplantar_keratoderma_and_erythrokeratoderma...  21135.0      528.375
# Mosaic_skin_disorders_-_deep_sequencing_GA          19561.0      489.025
# Palmoplantar_keratodermas_GA                        19546.0      488.650
# Pigmentary_skin_disorders_GA                        19552.0      488.800
# Primary_immunodeficiency_or_monogenic_inflammat...  22417.0      560.425
# Clefting_GA                                         19645.0      491.125
# Fetal_anomalies_GA                                  19586.0      489.650
# Fetal_hydrops_GA                                    20484.0      512.100
# Laterality_disorders_and_isomerism_GA               21136.0      528.400
# Radial_dysplasia_GA                                 22705.0      567.625
# RASopathies_GA                                      22805.0      570.125
# Severe_microcephaly_GA                              22019.0      550.475
# VACTERL-like_phenotypes_GA                          19464.0      486.600
# Vici_Syndrome_and_other_autophagy_disorders_GA      19699.0      492.475
# Xeroderma_pigmentosum,_Trichothiodystrophy_or_C...  22717.0      567.925
# Congenital_adrenal_hypoplasia_GA                    19734.0      493.350
# Congenital_hyperinsulinism_GA                       19644.0      491.100
# Congenital_hypothyroidism_GA                        19660.0      491.500
# Diabetes_with_additional_phenotypes_suggestive_...  19479.0      486.975
# Disorders_of_sex_development_GA                     19494.0      487.350
# Familial_diabetes_GA                                22197.0      554.925
# Familial_hyperparathyroidism_or_hypocalciuric_h...  19576.0      489.400
# Hypogonadotropic_hypogonadism_(GMS)_GA              19652.0      491.300
# Insulin_resistance_(including_lipodystrophy)_GA     19526.0      488.150
# IUGR_and_IGF_abnormalities_GA                       19435.0      485.875
# Monogenic_diabetes_GA                               22305.0      557.625
# Neonatal_diabetes_GA                                22209.0      555.225
# Pituitary_hormone_deficiency_GA                     19736.0      493.400
# Primary_ovarian_insufficiency_GA                    19411.0      485.275
# Severe_early-onset_obesity_GA                       21018.0      525.450
# Cholestasis_GA                                      19494.0      487.350
# Ductal_plate_malformation_GA                        19716.0      492.900
# Familial_Hirschsprung_Disease_GA                    19724.0      493.100
# Gastrointestinal_epithelial_barrier_disorders_GA    20426.0      510.650
# Gastrointestinal_neuromuscular_disorders_GA         20421.0      510.525
# Infantile_enterocolitis_&_monogenic_inflammator...  20419.0      510.475
# Intestinal_failure_or_congenital_diarrhoea_GA       22700.0      567.500
# Neonatal_cholestasis_GA                             19503.0      487.575
# Non-syndromic_familial_congenital_anorectal_mal...  20555.0      513.875
# Paediatric_pseudo-obstruction_syndrome_GA           19589.0      489.725
# Beckwith-Wiedemann_syndrome_(BWS)_and_other_con...  22224.0      555.600
# Growth_failure_in_early_childhood_GA                22257.0      556.425
# Inherited_bleeding_disorders_GA                     19452.0      486.300
# Autoinflammatory_disorders_GA                       19753.0      493.825
# Bleeding_and_platelet_disorders_GA                  20353.0      508.825
# Confirmed_Fanconi_anaemia_or_Bloom_syndrome_GA      22228.0      555.700
# Cytopenia_-_NOT_Fanconi_anaemia_GA                  20440.0      511.000
# Cytopenias_and_congenital_anaemias_GA               22224.0      555.600
# Hereditary_Erythrocytosis_GA                        19696.0      492.400
# Rare_anaemia_GA                                     19768.0      494.200
# Thrombophilia_with_a_likely_monogenic_cause_GA      19523.0      488.075
# Corneal_dystrophy_GA                                19512.0      487.800
# Deafness_and_congenital_structural_abnormalitie...  22304.0      557.600
# Monogenic_hearing_loss_GA                           19536.0      488.400
# Congenital_disorders_of_glycosylation_GA            20890.0      522.250
# Hyperammonaemia_GA                                  19638.0      490.950
# Hypophosphataemia_or_rickets_GA                     19740.0      493.500
# Iron_metabolism_disorders_-_NOT_common_HFE_muta...  19708.0      492.700
# Ketotic_hypoglycaemia_GA                            19578.0      489.450
# Mitochondrial_disorder_with_complex_I_deficienc...  20415.0      510.375
# Mitochondrial_disorder_with_complex_III_deficie...  20981.0      524.525
# Mitochondrial_disorder_with_complex_IV_deficien...  21763.0      544.075
# Mitochondrial_disorder_with_complex_V_deficienc...  20973.0      524.325
# Mitochondrial_DNA_maintenance_disorder_GA           21131.0      528.275
# Mucopolysaccharideosis,_Gaucher,_Fabry_GA           19555.0      488.875
# Peroxisomal_disorders_GA                            20483.0      512.075
# Pyruvate_dehydrogenase_(PDH)_deficiency_GA          19407.0      485.175
# Glycogen_storage_disease_GA                         19607.0      490.175
# Acute_rhabdomyolysis_GA                             19522.0      488.050
# Adult_onset_dystonia,_chorea_or_related_movemen...  19491.0      487.275
# Adult_onset_hereditary_spastic_paraplegia_GA        20441.0      511.025
# Adult_onset_leukodystrophy_GA                       19457.0      486.425
# Arthrogryposis_GA                                   22666.0      566.650
# Ataxia_and_cerebellar_anomalies_-_narrow_panel_GA   20781.0      519.525
# Autism_GA                                           20350.0      508.750
# Brain_channelopathy_GA                              19549.0      488.725
# Cerebellar_hypoplasia_GA                            21126.0      528.150
# Cerebral_vascular_malformations_GA                  22225.0      555.625
# Childhood_onset_dystonia,_chorea_or_related_mov...  19505.0      487.625
# Childhood_onset_hereditary_spastic_paraplegia_GA    19566.0      489.150
# Congenital_muscular_dystrophy_GA                    19504.0      487.600
# Congenital_myaesthenic_syndrome_GA                  21003.0      525.075
# Congenital_myopathy_GA                              20509.0      512.725
# Distal_myopathies_GA                                21153.0      528.825
# Early_onset_dementia_(encompassing_fronto-tempo...  19549.0      488.725
# Early_onset_dystonia_GA                             19688.0      492.200
# Early_onset_or_syndromic_epilepsy_GA                19001.0      475.025
# Familial_dysautonomia_GA                            19588.0      489.700
# Hereditary_ataxia_GA                                19500.0      487.500
# Hereditary_ataxia_with_onset_in_adulthood_GA        21722.0      543.050
# Hereditary_neuropathy_GA                            20392.0      509.800
# Hereditary_neuropathy_or_pain_disorder_GA           20347.0      508.675
# Hereditary_spastic_paraplegia_GA                    20497.0      512.425
# Holoprosencephaly_-_NOT_chromosomal_GA              22411.0      560.275
# Hydrocephalus_GA                                    22689.0      567.225
# Inherited_white_matter_disorders_GA                 20414.0      510.350
# Intellectual_disability_-_microarray_and_sequen...  19440.0      486.000
# Intracerebral_calcification_disorders_GA            20931.0      523.275
# Limb_girdle_muscular_dystrophies,_myofibrillar_...  19526.0      488.150
# Malformations_of_cortical_development_GA            20345.0      508.625
# Neuronal_ceroid_lipofuscinosis_GA                   21142.0      528.550
# Neurotransmitter_disorders_GA                       19509.0      487.725
# Paediatric_motor_neuronopathies_GA                  21291.0      532.275
# Pain_syndromes_GA                                   19546.0      488.650
# Parkinson_Disease_and_Complex_Parkinsonism_GA       19535.0      488.375
# Paroxysmal_central_nervous_system_disorders_GA      19515.0      487.875
# Rhabdomyolysis_and_metabolic_muscle_disorders_GA    19488.0      487.200
# Skeletal_Muscle_Channelopathies_GA                  19739.0      493.475
# Structural_basal_ganglia_disorders_GA               19637.0      490.925
# White_matter_disorders_and_cerebral_calcificati...  19494.0      487.350
# Hereditary_systemic_amyloidosis_GA                  20574.0      514.350
# Rare_genetic_inflammatory_skin_disorders_GA         19463.0      486.575
# Anophthalmia_or_microphthalmia_GA                   19704.0      492.600
# Bilateral_congenital_or_childhood_onset_catarac...  22703.0      567.575
# Corneal_abnormalities_GA                            21123.0      528.075
# Glaucoma_(developmental)_GA                         19732.0      493.300
# Infantile_nystagmus_GA                              19871.0      496.775
# Ocular_and_oculo-cutaneous_albinism_GA              22405.0      560.125
# Ocular_coloboma_GA                                  19526.0      488.150
# Optic_neuropathy_GA                                 21110.0      527.750
# Retinal_disorders_GA                                22523.0      563.075
# Atypical_haemolytic_uraemic_syndrome_GA             22112.0      552.800
# CAKUT_GA                                            22761.0      569.025
# Cystic_kidney_disease_GA                            20494.0      512.350
# Extreme_early-onset_hypertension_GA                 19559.0      488.975
# Nephrocalcinosis_or_nephrolithiasis_GA              19712.0      492.800
# Polycystic_liver_disease_GA                         19444.0      486.100
# Proteinuric_renal_disease_GA                        19648.0      491.200
# Renal_tubulopathies_GA                              19695.0      492.375
# Tubulointerstitial_kidney_disease_GA                20624.0      515.600
# Unexplained_kidney_failure_in_young_people_GA       19609.0      490.225
# Familial_pulmonary_fibrosis_GA                      19806.0      495.150
# Pneumothorax_-_familial_GA                          22158.0      553.950
# Pulmonary_fibrosis_familial_GA                      19673.0      491.825
# Ehlers_Danlos_syndrome_with_a_likely_monogenic_...  19718.0      492.950
# Periodic_fever_syndromes_GA                         19843.0      496.075
# Amelogenesis_imperfecta_GA                          19462.0      486.550
# Choanal_atresia_GA                                  21036.0      525.900
# Limb_disorders_GA                                   22571.0      564.275
# Osteogenesis_imperfecta_GA                          19522.0      488.050
# Osteopetrosis_GA                                    21029.0      525.725
# Rare_syndromic_craniosynostosis_or_isolated_mul...  19474.0      486.850
# Stickler_syndrome_GA                                19705.0      492.625
# Thoracic_dystrophies_GA                             20985.0      524.625
# Endocrine_neoplasia_GA                              19702.0      492.550
# Familial_breast_cancer_GA                           22255.0      556.375
# Familial_rhabdomyosarcoma_GA                        19586.0      489.650
# Familial_Tumours_Syndromes_of_the_central_&_per...  19701.0      492.525
# Inherited_ovarian_cancer_(without_breast_cancer...  22256.0      556.400
# Inherited_pancreatic_cancer_GA                      22256.0      556.400
# Inherited_phaeochromocytoma_and_paraganglioma_GA    19579.0      489.475
# Inherited_phaeochromocytoma_and_paraganglioma_e...  19655.0      491.375
# Inherited_predisposition_to_acute_myeloid_leuka...  19688.0      492.200
# Inherited_renal_cancer_GA                           19573.0      489.325
# Multiple_endocrine_tumours_GA                       19737.0      493.425
# Neurofibromatosis_Type_1_GA                         22228.0      555.700

# %%
top_bottom[top_bottom==True] = "TOP"
# Out:
# /tmp/ipykernel_2657181/2000337921.py:1: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'TOP' has dtype incompatible with bool, please explicitly cast to a compatible dtype first.
#   top_bottom[top_bottom==True] = "TOP"

# %%
top_bottom[mask_bottom == True] = "BOTTOM"

# %%
top_bottom
# Out:
#         Colorectal_cancer_pertinent_cancer_susceptibility_GA  \
# SYMBOL
# FAAP20                                               False
# FANCM                                                  TOP
# POT1                                                   TOP
# FAAP100                                              False
# XRCC3                                                  TOP
# ...                                                    ...
# MTSS1L                                              BOTTOM
# C2orf71                                             BOTTOM
# FAM57B                                              BOTTOM
# FAM92A                                              BOTTOM
# WISP3                                               BOTTOM
#
#         Head_and_neck_cancer_pertinent_cancer_susceptibility_GA  \
# SYMBOL
# FAAP20                                                 TOP
# FANCM                                                False
# POT1                                                   TOP
# FAAP100                                                TOP
# XRCC3                                                  TOP
# ...                                                    ...
# MTSS1L                                              BOTTOM
# C2orf71                                             BOTTOM
# FAM57B                                              BOTTOM
# FAM92A                                              BOTTOM
# WISP3                                               BOTTOM
#
#         Neuroendocrine_cancer_pertinent_cancer_susceptibility_GA  \
# SYMBOL
# FAAP20                                               False
# FANCM                                                False
# POT1                                                 False
# FAAP100                                              False
# XRCC3                                                False
# ...                                                    ...
# MTSS1L                                              BOTTOM
# C2orf71                                             BOTTOM
# FAM57B                                              BOTTOM
# FAM92A                                              BOTTOM
# WISP3                                               BOTTOM
#
#         Renal_cancer_pertinent_cancer_susceptibility_GA  \
# SYMBOL
# FAAP20                                            False
# FANCM                                             False
# POT1                                              False
# FAAP100                                           False
# XRCC3                                             False
# ...                                                 ...
# MTSS1L                                           BOTTOM
# C2orf71                                          BOTTOM
# FAM57B                                           BOTTOM
# FAM92A                                           BOTTOM
# WISP3                                            BOTTOM
#
#         Arrhythmogenic_right_ventricular_cardiomyopathy_GA  \
# SYMBOL
# FAAP20                                               False
# FANCM                                                False
# POT1                                                 False
# FAAP100                                              False
# XRCC3                                                False
# ...                                                    ...
# MTSS1L                                              BOTTOM
# C2orf71                                             BOTTOM
# FAM57B                                              BOTTOM
# FAM92A                                              BOTTOM
# WISP3                                               BOTTOM
#
#         ClinGen_Familial_thoracic_aortic_aneurysm_and_aortic_dissection_GA  \
# SYMBOL
# FAAP20                                              BOTTOM
# FANCM                                                False
# POT1                                                 False
# FAAP100                                              False
# XRCC3                                                False
# ...                                                    ...
# MTSS1L                                              BOTTOM
# C2orf71                                             BOTTOM
# FAM57B                                              BOTTOM
# FAM92A                                              BOTTOM
# WISP3                                               BOTTOM
#
#         Dilated_Cardiomyopathy_and_conduction_defects_GA  \
# SYMBOL
# FAAP20                                            BOTTOM
# FANCM                                              False
# POT1                                               False
# FAAP100                                           BOTTOM
# XRCC3                                              False
# ...                                                  ...
# MTSS1L                                            BOTTOM
# C2orf71                                           BOTTOM
# FAM57B                                            BOTTOM
# FAM92A                                            BOTTOM
# WISP3                                             BOTTOM
#
#         Familial_cerebral_small_vessel_disease_GA  \
# SYMBOL
# FAAP20                                     BOTTOM
# FANCM                                       False
# POT1                                        False
# FAAP100                                    BOTTOM
# XRCC3                                       False
# ...                                           ...
# MTSS1L                                     BOTTOM
# C2orf71                                    BOTTOM
# FAM57B                                     BOTTOM
# FAM92A                                     BOTTOM
# WISP3                                      BOTTOM
#
#         Familial_non_syndromic_congenital_heart_disease_GA  \
# SYMBOL
# FAAP20                                              BOTTOM
# FANCM                                                False
# POT1                                                 False
# FAAP100                                              False
# XRCC3                                                False
# ...                                                    ...
# MTSS1L                                              BOTTOM
# C2orf71                                             BOTTOM
# FAM57B                                              BOTTOM
# FAM92A                                              BOTTOM
# WISP3                                               BOTTOM
#
#         Hypertrophic_cardiomyopathy_GA  ... Familial_rhabdomyosarcoma_GA  \
# SYMBOL                                  ...
# FAAP20                          BOTTOM  ...                        False
# FANCM                            False  ...                          TOP
# POT1                             False  ...                        False
# FAAP100                         BOTTOM  ...                        False
# XRCC3                            False  ...                          TOP
# ...                                ...  ...                          ...
# MTSS1L                          BOTTOM  ...                       BOTTOM
# C2orf71                         BOTTOM  ...                       BOTTOM
# FAM57B                          BOTTOM  ...                       BOTTOM
# FAM92A                          BOTTOM  ...                       BOTTOM
# WISP3                           BOTTOM  ...                       BOTTOM
#
#         Familial_Tumours_Syndromes_of_the_central_&_peripheral_Nervous_system_GA  \
# SYMBOL
# FAAP20                                               False
# FANCM                                                  TOP
# POT1                                                 False
# FAAP100                                              False
# XRCC3                                                  TOP
# ...                                                    ...
# MTSS1L                                              BOTTOM
# C2orf71                                             BOTTOM
# FAM57B                                              BOTTOM
# FAM92A                                              BOTTOM
# WISP3                                               BOTTOM
#
#         Inherited_ovarian_cancer_(without_breast_cancer)_GA  \
# SYMBOL
# FAAP20                                               False
# FANCM                                                  TOP
# POT1                                                   TOP
# FAAP100                                                TOP
# XRCC3                                                  TOP
# ...                                                    ...
# MTSS1L                                              BOTTOM
# C2orf71                                             BOTTOM
# FAM57B                                              BOTTOM
# FAM92A                                              BOTTOM
# WISP3                                               BOTTOM
#
#         Inherited_pancreatic_cancer_GA  \
# SYMBOL
# FAAP20                             TOP
# FANCM                              TOP
# POT1                               TOP
# FAAP100                            TOP
# XRCC3                              TOP
# ...                                ...
# MTSS1L                          BOTTOM
# C2orf71                         BOTTOM
# FAM57B                          BOTTOM
# FAM92A                          BOTTOM
# WISP3                           BOTTOM
#
#         Inherited_phaeochromocytoma_and_paraganglioma_GA  \
# SYMBOL
# FAAP20                                             False
# FANCM                                              False
# POT1                                               False
# FAAP100                                            False
# XRCC3                                              False
# ...                                                  ...
# MTSS1L                                            BOTTOM
# C2orf71                                           BOTTOM
# FAM57B                                            BOTTOM
# FAM92A                                            BOTTOM
# WISP3                                             BOTTOM
#
#         Inherited_phaeochromocytoma_and_paraganglioma_excluding_NF1_GA  \
# SYMBOL
# FAAP20                                               False
# FANCM                                                False
# POT1                                                 False
# FAAP100                                              False
# XRCC3                                                False
# ...                                                    ...
# MTSS1L                                              BOTTOM
# C2orf71                                             BOTTOM
# FAM57B                                              BOTTOM
# FAM92A                                              BOTTOM
# WISP3                                               BOTTOM
#
#         Inherited_predisposition_to_acute_myeloid_leukaemia_(AML)_GA  \
# SYMBOL
# FAAP20                                               False
# FANCM                                                  TOP
# POT1                                                   TOP
# FAAP100                                              False
# XRCC3                                                  TOP
# ...                                                    ...
# MTSS1L                                              BOTTOM
# C2orf71                                             BOTTOM
# FAM57B                                              BOTTOM
# FAM92A                                              BOTTOM
# WISP3                                               BOTTOM
#
#         Inherited_renal_cancer_GA Multiple_endocrine_tumours_GA  \
# SYMBOL
# FAAP20                      False                         False
# FANCM                       False                         False
# POT1                          TOP                         False
# FAAP100                     False                         False
# XRCC3                       False                         False
# ...                           ...                           ...
# MTSS1L                     BOTTOM                        BOTTOM
# C2orf71                    BOTTOM                        BOTTOM
# FAM57B                     BOTTOM                        BOTTOM
# FAM92A                     BOTTOM                        BOTTOM
# WISP3                      BOTTOM                        BOTTOM
#
#         Neurofibromatosis_Type_1_GA
# SYMBOL
# FAAP20                          TOP
# FANCM                           TOP
# POT1                            TOP
# FAAP100                         TOP
# XRCC3                           TOP
# ...                             ...
# MTSS1L                       BOTTOM
# C2orf71                      BOTTOM
# FAM57B                       BOTTOM
# FAM92A                       BOTTOM
# WISP3                        BOTTOM
#
# [24757 rows x 183 columns]

# %%
class_top_bottom
# Out:
#         Cardiovascular disorders Renal and urinary tract disorders  \
# SYMBOL
# FAAP20                       NaN                               NaN
# FANCM                        NaN                               NaN
# POT1                         NaN                               NaN
# FAAP100                      NaN                               NaN
# XRCC3                        NaN                               NaN
# ...                          ...                               ...
# MTSS1L                       NaN                               NaN
# C2orf71                      NaN                               NaN
# FAM57B                       NaN                               NaN
# FAM92A                       NaN                               NaN
# WISP3                        NaN                               NaN
#
#         Respiratory disorders Gastroenterological disorders Ciliopathies  \
# SYMBOL
# FAAP20                    NaN                           NaN          NaN
# FANCM                     NaN                           NaN          NaN
# POT1                      NaN                           NaN          NaN
# FAAP100                   NaN                           NaN          NaN
# XRCC3                     NaN                           NaN          NaN
# ...                       ...                           ...          ...
# MTSS1L                    NaN                           NaN          NaN
# C2orf71                   NaN                           NaN          NaN
# FAM57B                    NaN                           NaN          NaN
# FAM92A                    NaN                           NaN          NaN
# WISP3                     NaN                           NaN          NaN
#
#         Growth disorders Ophthalmological disorders Skeletal disorders  \
# SYMBOL
# FAAP20               NaN                        NaN                NaN
# FANCM                NaN                        NaN                NaN
# POT1                 NaN                        NaN                NaN
# FAAP100              NaN                        NaN                NaN
# XRCC3                NaN                        NaN                NaN
# ...                  ...                        ...                ...
# MTSS1L               NaN                        NaN                NaN
# C2orf71              NaN                        NaN                NaN
# FAM57B               NaN                        NaN                NaN
# FAM92A               NaN                        NaN                NaN
# WISP3                NaN                        NaN                NaN
#
#         Haematological and immunological disorders Rheumatological disorders  \
# SYMBOL
# FAAP20                                         NaN                       NaN
# FANCM                                          NaN                       NaN
# POT1                                           NaN                       NaN
# FAAP100                                        NaN                       NaN
# XRCC3                                          NaN                       NaN
# ...                                            ...                       ...
# MTSS1L                                         NaN                       NaN
# C2orf71                                        NaN                       NaN
# FAM57B                                         NaN                       NaN
# FAM92A                                         NaN                       NaN
# WISP3                                          NaN                       NaN
#
#         Hearing and ear disorders Dermatological disorders  \
# SYMBOL
# FAAP20                        NaN                      NaN
# FANCM                         NaN                      NaN
# POT1                          NaN                      NaN
# FAAP100                       NaN                      NaN
# XRCC3                         NaN                      NaN
# ...                           ...                      ...
# MTSS1L                        NaN                      NaN
# C2orf71                       NaN                      NaN
# FAM57B                        NaN                      NaN
# FAM92A                        NaN                      NaN
# WISP3                         NaN                      NaN
#
#         Cancer Programme+Tumour syndromes  \
# SYMBOL
# FAAP20                                NaN
# FANCM                                 NaN
# POT1                                  NaN
# FAAP100                               NaN
# XRCC3                                 NaN
# ...                                   ...
# MTSS1L                                NaN
# C2orf71                               NaN
# FAM57B                                NaN
# FAM92A                                NaN
# WISP3                                 NaN
#
#         Dysmorphic and congenital abnormality syndromes  \
# SYMBOL
# FAAP20                                              NaN
# FANCM                                               NaN
# POT1                                                NaN
# FAAP100                                             NaN
# XRCC3                                               NaN
# ...                                                 ...
# MTSS1L                                              NaN
# C2orf71                                             NaN
# FAM57B                                              NaN
# FAM92A                                              NaN
# WISP3                                               NaN
#
#         Neurology and neurodevelopmental disorders Endocrine disorders  \
# SYMBOL
# FAAP20                                         NaN                 NaN
# FANCM                                          NaN                 NaN
# POT1                                           NaN                 NaN
# FAAP100                                        NaN                 NaN
# XRCC3                                          NaN                 NaN
# ...                                            ...                 ...
# MTSS1L                                         NaN                 NaN
# C2orf71                                        NaN                 NaN
# FAM57B                                         NaN                 NaN
# FAM92A                                         NaN                 NaN
# WISP3                                          NaN                 NaN
#
#         Metabolic disorders
# SYMBOL
# FAAP20                  NaN
# FANCM                   NaN
# POT1                    NaN
# FAAP100                 NaN
# XRCC3                   NaN
# ...                     ...
# MTSS1L                  NaN
# C2orf71                 NaN
# FAM57B                  NaN
# FAM92A                  NaN
# WISP3                   NaN
#
# [24757 rows x 17 columns]

# %%
## ejemplo:
g = "FANCM"
c = "Cancer Programme+Tumour syndromes"
top_bottom.loc[g,panel_class[panel_class[0]==c][1]]
# Out:
# Colorectal_cancer_pertinent_cancer_susceptibility_GA                          TOP
# Head_and_neck_cancer_pertinent_cancer_susceptibility_GA                     False
# Neuroendocrine_cancer_pertinent_cancer_susceptibility_GA                    False
# Renal_cancer_pertinent_cancer_susceptibility_GA                             False
# Endocrine_neoplasia_GA                                                        TOP
# Familial_breast_cancer_GA                                                     TOP
# Familial_rhabdomyosarcoma_GA                                                  TOP
# Familial_Tumours_Syndromes_of_the_central_&_peripheral_Nervous_system_GA      TOP
# Inherited_ovarian_cancer_(without_breast_cancer)_GA                           TOP
# Inherited_pancreatic_cancer_GA                                                TOP
# Inherited_phaeochromocytoma_and_paraganglioma_GA                            False
# Inherited_phaeochromocytoma_and_paraganglioma_excluding_NF1_GA              False
# Inherited_predisposition_to_acute_myeloid_leukaemia_(AML)_GA                  TOP
# Inherited_renal_cancer_GA                                                   False
# Multiple_endocrine_tumours_GA                                               False
# Neurofibromatosis_Type_1_GA                                                   TOP
# Name: FANCM, dtype: object

# %%
gene_disease_matrix.loc[g,panel_class[panel_class[0]==c][1]]
# Out:
# Colorectal_cancer_pertinent_cancer_susceptibility_GA                          64.0
# Head_and_neck_cancer_pertinent_cancer_susceptibility_GA                        0.0
# Neuroendocrine_cancer_pertinent_cancer_susceptibility_GA                    6109.0
# Renal_cancer_pertinent_cancer_susceptibility_GA                              579.0
# Endocrine_neoplasia_GA                                                       141.0
# Familial_breast_cancer_GA                                                    159.0
# Familial_rhabdomyosarcoma_GA                                                 143.0
# Familial_Tumours_Syndromes_of_the_central_&_peripheral_Nervous_system_GA     189.0
# Inherited_ovarian_cancer_(without_breast_cancer)_GA                           20.0
# Inherited_pancreatic_cancer_GA                                                65.0
# Inherited_phaeochromocytoma_and_paraganglioma_GA                            6115.0
# Inherited_phaeochromocytoma_and_paraganglioma_excluding_NF1_GA              7112.0
# Inherited_predisposition_to_acute_myeloid_leukaemia_(AML)_GA                 316.0
# Inherited_renal_cancer_GA                                                   6501.0
# Multiple_endocrine_tumours_GA                                               3855.0
# Neurofibromatosis_Type_1_GA                                                    1.0
# Name: FANCM, dtype: float64

# %%
for g in top_bottom.index:
    for c in set(panel_class[0]):
        position_class = top_bottom.loc[g,panel_class[panel_class[0]==c][1]]
        top_in_class = np.sum(position_class == "TOP")
        bottom_in_class = np.sum(position_class == "BOTTOM")
        n_panels_class = len(position_class)
        if top_in_class > n_panels_class*0.5:
            class_top_bottom.loc[g, c] = "TOP"
        elif bottom_in_class > n_panels_class*0.5:
            class_top_bottom.loc[g, c] = "BOTTOM"
        else: 
            class_top_bottom.loc[g, c] = "MIDDLE"
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[189], line 4
#       2 for c in set(panel_class[0]):
#       3     position_class = top_bottom.loc[g,panel_class[panel_class[0]==c][1]]
# ----> 4     top_in_class = np.sum(position_class == "TOP")
#       5     bottom_in_class = np.sum(position_class == "BOTTOM")
#       6     n_panels_class = len(position_class)
#
# File ~/miniconda3/envs/spyder-env/lib/python3.12/site-packages/pandas/core/ops/common.py:76, in _unpack_zerodim_and_defer.<locals>.new_method(self, other)
#      72             return NotImplemented
#      74 other = item_from_zerodim(other)
# ---> 76 return method(self, other)
#
# File ~/miniconda3/envs/spyder-env/lib/python3.12/site-packages/pandas/core/arraylike.py:40, in OpsMixin.__eq__(self, other)
#      38 @unpack_zerodim_and_defer("__eq__")
#      39 def __eq__(self, other):
# ---> 40     return self._cmp_method(other, operator.eq)
#
# File ~/miniconda3/envs/spyder-env/lib/python3.12/site-packages/pandas/core/series.py:6110, in Series._cmp_method(self, other, op)
#    6107 lvalues = self._values
#    6108 rvalues = extract_array(other, extract_numpy=True, extract_range=True)
# -> 6110 res_values = ops.comparison_op(lvalues, rvalues, op)
#    6112 return self._construct_result(res_values, name=res_name)
#
# File ~/miniconda3/envs/spyder-env/lib/python3.12/site-packages/pandas/core/ops/array_ops.py:344, in comparison_op(left, right, op)
#     341     return invalid_comparison(lvalues, rvalues, op)
#     343 elif lvalues.dtype == object or isinstance(rvalues, str):
# --> 344     res_values = comp_method_OBJECT_ARRAY(op, lvalues, rvalues)
#     346 else:
#     347     res_values = _na_arithmetic_op(lvalues, rvalues, op, is_cmp=True)
#
# File ~/miniconda3/envs/spyder-env/lib/python3.12/site-packages/pandas/core/ops/array_ops.py:113, in comp_method_OBJECT_ARRAY(op, x, y)
#     108             right[right_mask & mask] = fill_value
#     110     return left, right
# --> 113 def comp_method_OBJECT_ARRAY(op, x, y):
#     114     if isinstance(y, list):
#     115         # e.g. test_tuple_categories
#     116         y = construct_1d_object_array_from_listlike(y)
#
# KeyboardInterrupt:

# %%
class_top_bottom

# %%
gen_n_class_top = np.sum(class_top_bottom == "TOP", axis=1)
gen_n_class_bottom = np.sum(class_top_bottom == "BOTTOM", axis=1)

# %%
ranking_n_class = pd.DataFrame(
    {'n_top': gen_n_class_top,
     'n_bottom': gen_n_class_bottom
    })

ranking_n_class

# %%
ranking_n_class[ranking_n_class["n_top"] > 1]

# %%
top_1_class=ranking_n_class.query('n_top == 1 and n_bottom >= 10' )  # hay 17 clases en total. 
top_1_class

# %% [markdown]
# Con un threshold de 0.05 y seleccionando genes con una categoría TOP y más de 10 bottom, salen 251 genes.

# %%
#gen="UQCR11"
#list(class_top_bottom.loc[gen][class_top_bottom.loc[gen] == "TOP"].index)[0]

# %%
##top_1_class.to_csv("/home/yolanda/tblab/yolanda/GLOWgenes/panelAPP/revision/specific_genes/genes_class_specific_laxo.txt")

# %%
[x for x in top_1_class.index if x in list(genes_panelApp[0]) ]

# %%
gene_disease_matrix.loc["FAAP20",panel_class[panel_class[0]=="Cancer Programme+Tumour syndromes"][1]]
#gene_disease_matrix.loc["FAAP20"]

# %%
for gen in top_1_class.index: 
    print(gen + ": " + list(class_top_bottom.loc[gen][class_top_bottom.loc[gen] == "TOP"].index)[0])

# %% [markdown]
# **UQCR10 sale en red en mitocondriales y sale específico de metabolismo**
# **SOBP sale en red en monogenic hearing loss y sale específico de hearing disorders**

# %%
top_clases = []
for gen in top_1_class.index: 
    top_clases.append(list(class_top_bottom.loc[gen][class_top_bottom.loc[gen] == "TOP"].index)[0])

from collections import Counter

d = Counter(top_clases)

d

# %% [markdown]
# Todos, menos OPN1LW y UQCR11 son específicos de Respiratory disorders o de Ciliopatías.

# %% [markdown]
# Relajamos el threshold. Solo los que son top en una categoría (sin restricción de bottom)

# %%
top_1_class=ranking_n_class.query('n_top == 1 and n_bottom!=0' )  # hay 17 clases en total. 
#top_1_class=ranking_n_class.query('n_top == 1' ) 
top_1_class

# %%
for gen in top_1_class.index: 
    print(gen + ": " + list(class_top_bottom.loc[gen][class_top_bottom.loc[gen] == "TOP"].index)[0])

# %%
class_specific = {}
for gen in top_1_class.index: 
    class_specific[gen] = list(class_top_bottom.loc[gen][class_top_bottom.loc[gen] == "TOP"].index)[0]
    #print(gen + ": " + list(class_top_bottom.loc[gen][class_top_bottom.loc[gen] == "TOP"].index)[0])

# %%
class_specific

# %%
df_class_specific = pd.DataFrame.from_dict(class_specific, orient = "index", columns=["Class"])

# %%
df_class_specific.to_csv(str("/home/yolanda/tblab/yolanda/GLOWgenes/panelAPP/revision/specific_genes/genes_class_specific_class_top_"+ str(threshold_top) + "_bottom_"+str(threshold_bottom) +".csv"), header=False)

# %%
top_clases = []
for gen in top_1_class.index: 
    top_clases.append(list(class_top_bottom.loc[gen][class_top_bottom.loc[gen] == "TOP"].index)[0])

# %%
from collections import Counter

d = Counter(top_clases)

d
# Out:
# Counter({'Ciliopathies': 133,
#          'Respiratory disorders': 53,
#          'Dermatological disorders': 28,
#          'Ophthalmological disorders': 9,
#          'Cancer Programme+Tumour syndromes': 5,
#          'Renal and urinary tract disorders': 4,
#          'Cardiovascular disorders': 4,
#          'Rheumatological disorders': 4,
#          'Hearing and ear disorders': 3,
#          'Endocrine disorders': 2,
#          'Metabolic disorders': 1,
#          'Haematological and immunological disorders': 1,
#          'Skeletal disorders': 1})

# %%
import pandas as pd
genes_top1_class = pd.read_csv(str("/home/yolanda/tblab/yolanda/GLOWgenes/panelAPP/revision/specific_genes/genes_class_specific_top_"+ str(threshold_top) + "_bottom_"+str(threshold_bottom) +".txt"),sep = ',') 
genes_top1_class
#genes_panelApp = pd.read_csv('/home/yolanda/tblab/yolanda/GLOWgenes/panelAPP/PANELAPP_ALL_GENES_sep.txt',sep = '\t', header=None) 
#genes_panelApp
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[150], line 2
#       1 import pandas as pd
# ----> 2 genes_top1_class = pd.read_csv(str("/home/yolanda/tblab/yolanda/GLOWgenes/panelAPP/revision/specific_genes/genes_class_specific_top_"+ str(threshold_top) + "_bottom_"+str(threshold_bottom) +".txt"),sep = ',')
#       3 genes_top1_class
#       4 #genes_panelApp = pd.read_csv('/home/yolanda/tblab/yolanda/GLOWgenes/panelAPP/PANELAPP_ALL_GENES_sep.txt',sep = '\t', header=None)
#       5 #genes_panelApp
#
# File ~/miniconda3/envs/spyder-env/lib/python3.12/site-packages/pandas/io/parsers/readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1013 kwds_defaults = _refine_defaults_read(
#    1014     dialect,
#    1015     delimiter,
#    (...)
#    1022     dtype_backend=dtype_backend,
#    1023 )
#    1024 kwds.update(kwds_defaults)
# -> 1026 return _read(filepath_or_buffer, kwds)
#
# File ~/miniconda3/envs/spyder-env/lib/python3.12/site-packages/pandas/io/parsers/readers.py:620, in _read(filepath_or_buffer, kwds)
#     617 _validate_names(kwds.get("names", None))
#     619 # Create the parser.
# --> 620 parser = TextFileReader(filepath_or_buffer, **kwds)
#     622 if chunksize or iterator:
#     623     return parser
#
# File ~/miniconda3/envs/spyder-env/lib/python3.12/site-packages/pandas/io/parsers/readers.py:1620, in TextFileReader.__init__(self, f, engine, **kwds)
#    1617     self.options["has_index_names"] = kwds["has_index_names"]
#    1619 self.handles: IOHandles | None = None
# -> 1620 self._engine = self._make_engine(f, self.engine)
#
# File ~/miniconda3/envs/spyder-env/lib/python3.12/site-packages/pandas/io/parsers/readers.py:1880, in TextFileReader._make_engine(self, f, engine)
#    1878     if "b" not in mode:
#    1879         mode += "b"
# -> 1880 self.handles = get_handle(
#    1881     f,
#    1882     mode,
#    1883     encoding=self.options.get("encoding", None),
#    1884     compression=self.options.get("compression", None),
#    1885     memory_map=self.options.get("memory_map", False),
#    1886     is_text=is_text,
#    1887     errors=self.options.get("encoding_errors", "strict"),
#    1888     storage_options=self.options.get("storage_options", None),
#    1889 )
#    1890 assert self.handles is not None
#    1891 f = self.handles.handle
#
# File ~/miniconda3/envs/spyder-env/lib/python3.12/site-packages/pandas/io/common.py:873, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     868 elif isinstance(handle, str):
#     869     # Check whether the filename is to be opened in binary mode.
#     870     # Binary mode does not support 'encoding' and 'newline'.
#     871     if ioargs.encoding and "b" not in ioargs.mode:
#     872         # Encoding
# --> 873         handle = open(
#     874             handle,
#     875             ioargs.mode,
#     876             encoding=ioargs.encoding,
#     877             errors=errors,
#     878             newline="",
#     879         )
#     880     else:
#     881         # Binary mode
#     882         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: '/home/yolanda/tblab/yolanda/GLOWgenes/panelAPP/revision/specific_genes/genes_class_specific_top_0.05_bottom_0.5.txt'

# %%
[x for x in genes_top1_class["SYMBOL"] if x in list(genes_panelApp[0]) ]
# Out:
# ['POT1',
#  'TERF2',
#  'MSH3',
#  'RAD51',
#  'TERF2IP',
#  'FAN1',
#  'STN1',
#  'RPA1',
#  'MDM2',
#  'ATR',
#  'PIK3CA',
#  'NBN',
#  'XRCC2',
#  'BARD1',
#  'MRE11',
#  'RECQL4',
#  'DCLRE1B',
#  'XRCC1',
#  'RAD50',
#  'ATRX',
#  'CCND1',
#  'KLLN',
#  'EGFR',
#  'PDGFRA',
#  'EP300',
#  'FGFR2',
#  'USB1',
#  'MSH5',
#  'MSH4',
#  'SMC1A',
#  'KMT2D',
#  'STAT3',
#  'IDH1',
#  'GLI3',
#  'ARID1B',
#  'ERBB3',
#  'FOS',
#  'SMO',
#  'CCNA2',
#  'IGF2',
#  'GNA11',
#  'PAX6',
#  'BMP4',
#  'PLK4',
#  'GLI2',
#  'GJA1',
#  'STAT5A',
#  'IGF1',
#  'INS',
#  'PAX2',
#  'FGF8',
#  'PCNT',
#  'PAX8',
#  'EGR2',
#  'SHQ1',
#  'MDH2',
#  'HDAC3',
#  'TPP1',
#  'CSF2',
#  'NEK2',
#  'BBS4',
#  'BMP2',
#  'FOXC1',
#  'RPGRIP1L',
#  'FN1',
#  'LYST',
#  'CDK20',
#  'BMP7',
#  'CEP290',
#  'CENPJ',
#  'PAX1',
#  'EPOR',
#  'B9D1',
#  'RAB23',
#  'IFT172',
#  'SMG6',
#  'COL7A1',
#  'DYNC2H1',
#  'CC2D2A',
#  'UPF1',
#  'EIF2AK4',
#  'ALX4',
#  'FGF20',
#  'POC1A',
#  'KRT5',
#  'OGDH',
#  'IFT140',
#  'STIL',
#  'COL2A1',
#  'OCA2',
#  'POMC',
#  'SOX3',
#  'ISL1',
#  'TERB2',
#  'NEUROD1',
#  'IFT88',
#  'EXOSC3',
#  'FOXJ1',
#  'MSX1',
#  'IFT80',
#  'IL3',
#  'FOXD3',
#  'IFT122',
#  'HPS6',
#  'KRT9',
#  'WDR19',
#  'SIX2',
#  'DLX5',
#  'FUZ',
#  'SERPINA1',
#  'EXOSC8',
#  'HOXB1',
#  'CEP152',
#  'IFT27',
#  'TULP3',
#  'AP3D1',
#  'HPS5',
#  'APOA1',
#  'NPHP3',
#  'HPS3',
#  'IL17RD',
#  'SLC45A2',
#  'DYNC2LI1',
#  'PRRX1',
#  'EXOSC2',
#  'MYL2',
#  'LAMA4',
#  'DMBT1',
#  'ARL3',
#  'GJA5',
#  'NEK9',
#  'IL3RA',
#  'EXOSC1',
#  'DSG1',
#  'KIF3B',
#  'KIF17',
#  'BLOC1S3',
#  'CFAP20',
#  'RPGRIP1',
#  'DCTN1',
#  'CEP295',
#  'NEUROG1',
#  'CRYBA4',
#  'RFX3',
#  'CEP135',
#  'POU3F3',
#  'RPGR',
#  'GBX2',
#  'CBY1',
#  'RYR2',
#  'NEK8',
#  'SIX3',
#  'GALC',
#  'PDE6D',
#  'RFX4',
#  'MAK',
#  'DYNC1H1',
#  'INTU',
#  'GAS8',
#  'KRT16',
#  'TTC21B',
#  'GPR161',
#  'BBIP1',
#  'ACAD9',
#  'TTBK2',
#  'PKD1L1',
#  'DTNBP1',
#  'RAX',
#  'BLOC1S6',
#  'SASS6',
#  'CACNB2',
#  'CEP63',
#  'AQP5',
#  'KCNQ1',
#  'FBF1',
#  'KRT6A',
#  'NPPA',
#  'TTC26',
#  'TBC1D32',
#  'SPATA7',
#  'RP2',
#  'GSX2',
#  'KRT6B',
#  'DYNC1I2',
#  'RAB32',
#  'CROCC',
#  'NIN',
#  'MYL3',
#  'NPHP4',
#  'ELMOD2',
#  'CLUAP1',
#  'CEP83',
#  'CASQ2',
#  'FAM161A',
#  'MYOZ2',
#  'DSC1',
#  'KCNA5',
#  'CEP250',
#  'IFT81',
#  'CRYAA',
#  'CEP78',
#  'IFT74',
#  'SFTPD',
#  'CEP89',
#  'NUDCD3',
#  'CEP19',
#  'LCA5',
#  'CCDC28B',
#  'TCTEX1D2',
#  'BRCA2',
#  'CDH1',
#  'CDKN2A',
#  'CHEK2',
#  'ERCC1',
#  'ERCC4',
#  'ERCC5',
#  'HRAS',
#  'KRAS',
#  'PTCH1',
#  'RAD51D',
#  'RB1',
#  'SDHA',
#  'SMARCA4',
#  'TSC2',
#  'WRAP53',
#  'XPA']

# %% [markdown]
# ELMOD2 está en los red de Familial pulmonary fibrosis
# IFT74 red en Renal ciliopathies
# CCDC28B red en varias ciliopathies

# %% [markdown]
# Vamos a probar añadiendo la condición de que el 50% de los paneles tienen que estar en el bottom (183 paneles * 0.5 = 91 paneles):

# %%
top_1_class=ranking_n_class.query('n_top == 1' )  # hay 17 clases en total. 
top_1_class
# Out:
#           n_top  n_bottom
# SYMBOL
# POT1          1         4
# TERF2         1         1
# TEN1          1         6
# TERF2IP       1         3
# FAN1          1         2
# ...         ...       ...
# TCTEX1D1      1        13
# SNTN          1        16
# C5ORF52       1        16
# ERCC4         1         1
# WRAP53        1         1
#
# [215 rows x 2 columns]

# %%
bottom_05 = ranking_n[ranking_n["n_bottom"] > 91] 
bottom_05
# Out:
#          n_top  n_bottom
# SYMBOL
# FAAP20      11       139
# FAAP100     14       117
# TEN1        12        96
# CENPS       11        95
# KLLN        15        96
# ...        ...       ...
# MTSS1L       0       182
# C2orf71      0       182
# FAM57B       0       182
# FAM92A       0       182
# WISP3        0       183
#
# [14318 rows x 2 columns]

# %%
esp_clase_05 = [x for x in list(top_1_class.index) if x in list(bottom_05.index)]

# %%
top_1_class_05= top_1_class.loc[esp_clase_05]
top_1_class_05
# Out:
#           n_top  n_bottom
# SYMBOL
# TEN1          1         6
# KLLN          1         9
# USB1          1         5
# SHQ1          1         9
# HMBOX1        1         7
# ...         ...       ...
# LYPD2         1        13
# BPIFB1        1        11
# TCTEX1D1      1        13
# SNTN          1        16
# C5ORF52       1        16
#
# [93 rows x 2 columns]

# %%
for gen in top_1_class_05.index: 
    print(gen + ": " + list(class_top_bottom.loc[gen][class_top_bottom.loc[gen] == "TOP"].index)[0])
# Out:
# TEN1: Respiratory disorders
# KLLN: Cancer Programme+Tumour syndromes
# USB1: Respiratory disorders
# SHQ1: Respiratory disorders
# HMBOX1: Respiratory disorders
# MAJIN: Respiratory disorders
# TERB2: Respiratory disorders
# SPOUT1: Respiratory disorders
# NUPR2: Respiratory disorders
# KRT9: Dermatological disorders
# ADPRH: Respiratory disorders
# EXOSC1: Respiratory disorders
# BLOC1S3: Respiratory disorders
# CFAP20: Ciliopathies
# CEP295: Ciliopathies
# EXOSC7: Respiratory disorders
# CRYBA4: Ophthalmological disorders
# GAS8: Ciliopathies
# KRT16: Dermatological disorders
# MOK: Ciliopathies
# BBIP1: Ciliopathies
# PKD1L1: Ciliopathies
# CLDN18: Respiratory disorders
# UBXN10: Ciliopathies
# CCDC18: Ciliopathies
# FBF1: Ciliopathies
# TTC26: Ciliopathies
# TBC1D32: Ciliopathies
# CEP131: Ciliopathies
# SPATA7: Ciliopathies
# RP2: Ciliopathies
# KRT6B: Dermatological disorders
# PIFO: Ciliopathies
# TTC21A: Ciliopathies
# ODF2: Ciliopathies
# KATNIP: Ciliopathies
# IFT46: Ciliopathies
# IL5RA: Respiratory disorders
# SCGB3A1: Respiratory disorders
# ELMOD2: Respiratory disorders
# CLUAP1: Ciliopathies
# IFT20: Ciliopathies
# IFT22: Ciliopathies
# CEP83: Ciliopathies
# ADGRF5: Respiratory disorders
# TBCC: Ciliopathies
# CDKL1: Ciliopathies
# CEP192: Ciliopathies
# RBM7: Respiratory disorders
# C10ORF131: Ciliopathies
# FAM161A: Ciliopathies
# BPIFA1: Respiratory disorders
# CC2D2B: Ciliopathies
# DSC1: Dermatological disorders
# SCGB3A2: Respiratory disorders
# CFAP36: Ciliopathies
# DYNLRB2: Ciliopathies
# LRRCC1: Ciliopathies
# IFT81: Ciliopathies
# CEP20: Ciliopathies
# TCTE3: Ciliopathies
# CDKL4: Ciliopathies
# CEP78: Ciliopathies
# IFT74: Ciliopathies
# CEP76: Ciliopathies
# CEP89: Ciliopathies
# CEP162: Ciliopathies
# NUDCD3: Ciliopathies
# CEP19: Ciliopathies
# RBM11: Respiratory disorders
# TMEM80: Ciliopathies
# PGA4: Respiratory disorders
# ARL13A: Ciliopathies
# PGA3: Respiratory disorders
# CCDC63: Ciliopathies
# SFTA2: Respiratory disorders
# CCDC14: Ciliopathies
# BIVM: Ciliopathies
# TTC30A: Ciliopathies
# TMEM268: Respiratory disorders
# TCTEX1D4: Ciliopathies
# TTC30B: Ciliopathies
# CCDC66: Ciliopathies
# CCDC28B: Ciliopathies
# SFTA3: Respiratory disorders
# TCTEX1D2: Ciliopathies
# TMEM17: Ciliopathies
# TEX9: Ciliopathies
# LYPD2: Respiratory disorders
# BPIFB1: Respiratory disorders
# TCTEX1D1: Ciliopathies
# SNTN: Respiratory disorders
# C5ORF52: Ciliopathies

# %%
top_clases_05 = []
for gen in top_1_class_05.index: 
    top_clases_05.append(list(class_top_bottom.loc[gen][class_top_bottom.loc[gen] == "TOP"].index)[0])

# %%
from collections import Counter

d = Counter(top_clases_05)

d
# Out:
# Counter({'Ciliopathies': 58,
#          'Respiratory disorders': 29,
#          'Dermatological disorders': 4,
#          'Cancer Programme+Tumour syndromes': 1,
#          'Ophthalmological disorders': 1})

# %%
top_1_class_05.to_csv("/home/yolanda/tblab/yolanda/GLOWgenes/panelAPP/analysis/genes_specific/genes_class_specific_05.txt")

# %%
ranking_n_class.query('n_top > 1' )
# Out:
#         n_top  n_bottom
# SYMBOL
# CTNNB1      4         0
# BLM         2         0
# WRN         2         0
# AKT1        4         0
# MYC         2         0
# FGFR1       2         0
# JAK2        3         0
# ESR1        2         0
# SHH         3         0
# SOX9        2         0
# WNT5A       2         0
# IRS1        2         0
# POU5F1      2         0
# ATM         2         0
# BRCA1       2         0
# CDK4        2         0
# KIT         3         0
# TP53        3         0

# %% [markdown]
# # Vemos si hay específicos de clase dentro de los específicos de enfermedad

# %%
list(top_1.index) in list(top_1_class.index)
# Out:
# False

# %%
[(x in list(top_1_class.index)) for x in list(top_1.index)]
# Out:
# [False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  True,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False]

# %%
def intersection(lst1, lst2):
    return list(set(lst1) & set(lst2))

print(intersection(list(top_1_class.index), list(top_1.index)))
# Out:
# []

# %% [markdown]
# No coincide ningún gen.

# %% [markdown]
# ----------

# %%
top_2_class=ranking_n_class.query('n_top == 0' )  # hay 17 clases en total. 
top_2_class # No hay casi paneles con más de una clase top???? raro?
# Out:
#          n_top  n_bottom
# SYMBOL
# FAAP20       0        14
# UBE2T        0         0
# CENPS        0        10
# GTF2H4       0         3
# NOP10        0         3
# ...        ...       ...
# MTSS1L       0        17
# C2orf71      0        17
# FAM57B       0        17
# FAM92A       0        17
# WISP3        0        17
#
# [21869 rows x 2 columns]

# %%
ranking_n["n_panels"] = 181
ranking_n
# Out:
#          n_top  n_bottom  n_panels
# SYMBOL
# FAAP20      16       135       181
# FANCM       25         6       181
# POT1        19        56       181
# FAAP100     18       108       181
# XRCC3       20        17       181
# ...        ...       ...       ...
# MTSS1L       0       180       181
# C2orf71      0       180       181
# FAM57B       0       180       181
# FAM92A       0       180       181
# WISP3        0       180       181
#
# [24757 rows x 3 columns]

# %%
specificity_score = (ranking_n["n_top"] / 181 ) * (ranking_n["n_bottom"] / 181 )

# %%
specificity_score /= (ranking_n["n_top"] + 1)

# %%
specificity_score
# Out:
# SYMBOL
# FAAP20     0.003878
# FANCM      0.000176
# POT1       0.001624
# FAAP100    0.003123
# XRCC3      0.000494
#              ...
# MTSS1L     0.000000
# C2orf71    0.000000
# FAM57B     0.000000
# FAM92A     0.000000
# WISP3      0.000000
# Length: 24757, dtype: float64

# %%
specificity_score["SYMBOL"] = specificity_score.index

# %%
specificity_score
# Out:
# SYMBOL
# FAAP20                                              0.003878
# FANCM                                               0.000176
# POT1                                                0.001624
# FAAP100                                             0.003123
# XRCC3                                               0.000494
#                                  ...
# C2orf71                                                  0.0
# FAM57B                                                   0.0
# FAM92A                                                   0.0
# WISP3                                                    0.0
# SYMBOL     Index(['FAAP20', 'FANCM', 'POT1', 'FAAP100', '...
# Length: 24758, dtype: object

# %%
#specificity_score.to_csv("/home/yolanda/tblab/yolanda/GLOWgenes/panelAPP/analysis/genes_specific/score_prueba.txt")
